# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/PMTese/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install python-docx

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.14.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Configs

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_all = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
]

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_FD001_Corr = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD001_Boruta=[
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Corr = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Boruta = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
def run_transformer_experiment(config):

    dataset_name = config["dataset_name"]
    scaler_type = config["scaler_type"]
    seq_length = config["seq_length"]
    use_piecewise_rul = config["use_piecewise_rul"]
    max_rul_cap = config["max_rul_cap"]
    useful_sensor_cols = config["feature_set"]
    batch_size = config["batch_size"]
    epochs = config["epochs"]
    lstm_units = config["lstm_units"]
    dropout_rate = config["dropout_rate"]
    loss_function = config["loss_function"]
    head_size= config["head_size"]
    num_heads=4
    ff_dim=128
    num_transformer_blocks=2
    mlp_units=[128]
    dropout=0.1
    mlp_dropout=0.1
    embedding_dim=64

    column_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor{i}' for i in range(1, 22)]
    train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
    test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
    rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)

    train_data.columns = column_names
    test_data.columns = column_names
    rul_data.columns = ['RUL']
    rul_data['id'] = range(1, len(rul_data) + 1)

    max_cycle = train_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'cycle_max'})
    train_data = train_data.merge(max_cycle, on='id')
    train_data['RUL'] = train_data['cycle_max'] - train_data['cycle']
    train_data.drop(columns=['cycle_max'], inplace=True)

    max_cycle_test = test_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
    test_data = test_data.merge(max_cycle_test, on='id')
    test_data = test_data.merge(rul_data, on='id')
    test_data['RUL'] = test_data['RUL'] + test_data['max_cycle'] - test_data['cycle']
    test_data.drop(columns=['max_cycle'], inplace=True)

    if use_piecewise_rul:
        train_data['RUL'] = train_data['RUL'].clip(upper=max_rul_cap)
        test_data['RUL'] = test_data['RUL'].clip(upper=max_rul_cap)

    train_data = train_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]
    test_data = test_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]

    scaler = MinMaxScaler() if scaler_type == 'minmax' else StandardScaler()
    train_data[useful_sensor_cols] = scaler.fit_transform(train_data[useful_sensor_cols])
    test_data[useful_sensor_cols] = scaler.transform(test_data[useful_sensor_cols])

    def create_sequences(data, sequence_length):
        sequences, labels = [], []
        for engine_id in data['id'].unique():
            engine_data = data[data['id'] == engine_id]
            X = engine_data[useful_sensor_cols].values
            y = engine_data['RUL'].values
            for i in range(len(X) - sequence_length + 1):
                sequences.append(X[i:i+sequence_length])
                labels.append(y[i+sequence_length-1])
        return np.array(sequences), np.array(labels)

    X_train, y_train = create_sequences(train_data, seq_length)
    X_test, y_test = create_sequences(test_data, seq_length)

    def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
        # Attention block
        attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
        attn_output = layers.Dropout(dropout)(attn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)  # Add & Norm

        # Feed Forward block
        ff_output = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        ff_output = layers.Dropout(dropout)(ff_output)
        ff_output = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ff_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + ff_output)  # Add & Norm

        return x


    def build_model(input_shape):
        inputs = keras.Input(shape=input_shape)
        x = inputs

        # https://www.tensorflow.org/tutorials/structured_data/time_series
        x = layers.Dense(embedding_dim)(inputs)

        for _ in range(num_transformer_blocks):
            x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D()(x)
        for units in mlp_units:
            x = layers.Dense(units, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(1)(x)  # Predict RUL
        return keras.Model(inputs, outputs)

    model = build_model(X_train.shape[1:])
    model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["mae"])

    early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=64,
        callbacks=[early_stopping]
    )

    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test RMSE: {rmse:.2f}")
    print(f"Test MAE: {mae:.2f}")

    return model, y_pred, rmse, mae

# %%
def compare_datasets(test_configs):
    results = []
    num_configs = len(test_configs)
    for i, config in enumerate(test_configs):
        print(f"Running experiment {i + 1}/{num_configs} with config: {config['dataset_name']}, Scaler: {config['scaler_type']}, Seq Length: {config['seq_length']}, Piecewise RUL: {config['use_piecewise_rul']}, Features: {', '.join(config['feature_set'])}")
        model, y_pred, rmse, mae = run_transformer_experiment(config)
        result = {
            'dataset': config['dataset_name'],
            'rmse': rmse,
            'mae': mae,
            'config': config
        }
        results.append(result)
        print(f"\n--- Experiment {i + 1} Report ---")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")
        print(f"Settings: {config}")
    return results

# %%
from docx import Document

def save_experiment_to_docx(results_list, output_path="/content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_transformer_20250827_FD002_Corr.docx"):
    doc = Document()
    doc.add_heading("Transformer RUL Prediction Experiment Results", level=1)

    for i, res in enumerate(results_list):
        doc.add_heading(f"Experiment {i + 1} – Dataset: {res['dataset']}", level=2)
        doc.add_paragraph(f"RMSE: {res['rmse']:.2f}")
        doc.add_paragraph(f"MAE: {res['mae']:.2f}")
        doc.add_paragraph("Settings Used:")
        for key, value in res['config'].items():
            doc.add_paragraph(f"- {key}: {value}", style='List Bullet')

        doc.add_paragraph("")  # Blank line between experiments

    doc.save(output_path)
    print(f"✅ Document saved to {output_path}")

# %%
results = compare_datasets(test_configs_FD002_Corr)
save_experiment_to_docx(results)

# Create summary table
summary_df = pd.DataFrame([
    {
        'Dataset': r['dataset'],
        'RMSE': r['rmse'],
        'MAE': r['mae'],
        'Scaler': r['config']['scaler_type'],
        'Seq Length': r['config']['seq_length'],
        'Piecewise RUL': r['config']['use_piecewise_rul'],
        'Features': ', '.join(r['config']['feature_set'])
    }
    for r in results
])

display(summary_df)
# Out:
# Running experiment 1/4 with config: FD002, Scaler: minmax, Seq Length: 50, Piecewise RUL: True, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 153s 272ms/step - loss: 5656.0771 - mae: 63.8348 - val_loss: 2424.5686 - val_mae: 41.8826
# Epoch 2/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 135s 259ms/step - loss: 2082.2402 - mae: 39.5870 - val_loss: 1717.6383 - val_mae: 36.5825
# Epoch 3/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 253ms/step - loss: 1727.1459 - mae: 36.6885 - val_loss: 1718.2705 - val_mae: 36.5578
# Epoch 4/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 125s 244ms/step - loss: 1731.0205 - mae: 36.7616 - val_loss: 1718.9862 - val_mae: 36.5511
# Epoch 5/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 146s 252ms/step - loss: 1739.3757 - mae: 36.8809 - val_loss: 1720.2499 - val_mae: 36.5479
# Epoch 6/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 257ms/step - loss: 1720.3134 - mae: 36.5811 - val_loss: 1716.7660 - val_mae: 36.5582
# Epoch 7/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 254ms/step - loss: 1712.1626 - mae: 36.4511 - val_loss: 1720.8975 - val_mae: 36.5486
# Epoch 8/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 259ms/step - loss: 1718.2711 - mae: 36.6250 - val_loss: 1545.3041 - val_mae: 34.0510
# Epoch 9/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 136s 248ms/step - loss: 1536.4485 - mae: 33.8106 - val_loss: 1493.6462 - val_mae: 33.2471
# Epoch 10/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 257ms/step - loss: 1462.7914 - mae: 32.7916 - val_loss: 1442.5673 - val_mae: 32.7052
# Epoch 11/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 135s 263ms/step - loss: 1456.4365 - mae: 32.6565 - val_loss: 1441.2488 - val_mae: 32.3183
# Epoch 12/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 258ms/step - loss: 1458.5669 - mae: 32.8029 - val_loss: 1438.4882 - val_mae: 32.6367
# Epoch 13/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 145s 263ms/step - loss: 1437.3671 - mae: 32.4521 - val_loss: 1406.8606 - val_mae: 32.2166
# Epoch 14/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 254ms/step - loss: 1416.6835 - mae: 32.1597 - val_loss: 1430.5529 - val_mae: 32.4362
# Epoch 15/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 249ms/step - loss: 1419.2096 - mae: 32.2343 - val_loss: 1383.9735 - val_mae: 32.0513
# Epoch 16/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 147s 259ms/step - loss: 1394.4390 - mae: 31.9229 - val_loss: 1526.5022 - val_mae: 32.5048
# Epoch 17/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 250ms/step - loss: 1394.3502 - mae: 31.8238 - val_loss: 1444.2056 - val_mae: 32.6039
# Epoch 18/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 258ms/step - loss: 1374.3539 - mae: 31.5299 - val_loss: 1417.8778 - val_mae: 32.2594
# Epoch 19/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 135s 245ms/step - loss: 1347.6172 - mae: 31.2829 - val_loss: 1406.9135 - val_mae: 31.9600
# Epoch 20/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 241ms/step - loss: 1328.8071 - mae: 30.9906 - val_loss: 1334.4158 - val_mae: 31.0078
# Epoch 21/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 246ms/step - loss: 1294.4868 - mae: 30.4540 - val_loss: 1320.0635 - val_mae: 30.8527
# Epoch 22/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 245ms/step - loss: 1258.1399 - mae: 29.9974 - val_loss: 1330.7598 - val_mae: 30.7289
# Epoch 23/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 246ms/step - loss: 1211.5540 - mae: 29.4018 - val_loss: 1222.6161 - val_mae: 29.4020
# Epoch 24/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 123s 241ms/step - loss: 1194.4393 - mae: 29.0329 - val_loss: 1338.3478 - val_mae: 30.2657
# Epoch 25/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 125s 243ms/step - loss: 1173.3740 - mae: 28.6410 - val_loss: 1361.3563 - val_mae: 29.7152
# Epoch 26/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 124s 242ms/step - loss: 1096.2590 - mae: 27.5014 - val_loss: 1119.5686 - val_mae: 27.9928
# Epoch 27/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 238ms/step - loss: 1062.2644 - mae: 26.9382 - val_loss: 1082.1056 - val_mae: 27.0486
# Epoch 28/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 248ms/step - loss: 992.2399 - mae: 25.8822 - val_loss: 1312.2180 - val_mae: 28.8745
# Epoch 29/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 123s 240ms/step - loss: 1008.7518 - mae: 26.0527 - val_loss: 1211.2118 - val_mae: 28.5609
# Epoch 30/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 146s 247ms/step - loss: 987.4443 - mae: 25.6415 - val_loss: 1011.0462 - val_mae: 26.1927
# Epoch 31/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 242ms/step - loss: 940.5995 - mae: 24.9898 - val_loss: 1012.5629 - val_mae: 25.9349
# Epoch 32/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 149s 255ms/step - loss: 935.3376 - mae: 24.8466 - val_loss: 1067.8811 - val_mae: 26.2557
# Epoch 33/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 253ms/step - loss: 919.3520 - mae: 24.5356 - val_loss: 1251.4921 - val_mae: 28.6673
# Epoch 34/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 250ms/step - loss: 926.3260 - mae: 24.6460 - val_loss: 1011.0619 - val_mae: 25.4419
# Epoch 35/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 252ms/step - loss: 930.6706 - mae: 24.6865 - val_loss: 1178.6924 - val_mae: 27.9409
# Epoch 36/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 125s 243ms/step - loss: 899.9791 - mae: 24.3084 - val_loss: 977.3446 - val_mae: 24.9287
# Epoch 37/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 145s 249ms/step - loss: 863.5756 - mae: 23.6599 - val_loss: 1430.6746 - val_mae: 30.8152
# Epoch 38/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 245ms/step - loss: 900.8414 - mae: 24.3335 - val_loss: 964.3111 - val_mae: 24.9576
# Epoch 39/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 123s 240ms/step - loss: 860.6316 - mae: 23.6813 - val_loss: 1010.2924 - val_mae: 25.9854
# Epoch 40/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 242ms/step - loss: 836.1392 - mae: 23.3730 - val_loss: 918.7214 - val_mae: 24.3718
# Epoch 41/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 241ms/step - loss: 864.4045 - mae: 23.5997 - val_loss: 1281.8131 - val_mae: 27.7309
# Epoch 42/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 249ms/step - loss: 866.4996 - mae: 23.6305 - val_loss: 915.2995 - val_mae: 24.3820
# Epoch 43/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 249ms/step - loss: 815.8902 - mae: 22.8807 - val_loss: 896.4353 - val_mae: 24.5372
# Epoch 44/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 125s 243ms/step - loss: 811.4856 - mae: 22.8598 - val_loss: 849.3551 - val_mae: 23.4612
# Epoch 45/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 248ms/step - loss: 833.7923 - mae: 23.2349 - val_loss: 924.6100 - val_mae: 24.7722
# Epoch 46/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 254ms/step - loss: 835.1711 - mae: 23.1701 - val_loss: 922.7084 - val_mae: 24.5224
# Epoch 47/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 254ms/step - loss: 837.4310 - mae: 23.2576 - val_loss: 861.1871 - val_mae: 23.7308
# Epoch 48/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 846.4041 - mae: 23.3802 - val_loss: 896.9539 - val_mae: 24.3582
# Epoch 49/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 147s 265ms/step - loss: 803.8410 - mae: 22.7979 - val_loss: 931.9703 - val_mae: 24.4629
# Epoch 50/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 133s 259ms/step - loss: 800.2580 - mae: 22.6390 - val_loss: 954.8692 - val_mae: 25.1725
# Epoch 51/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 138s 250ms/step - loss: 805.1097 - mae: 22.7337 - val_loss: 866.5218 - val_mae: 23.7283
# Epoch 52/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 255ms/step - loss: 799.8470 - mae: 22.6543 - val_loss: 933.0472 - val_mae: 24.0914
# Epoch 53/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 258ms/step - loss: 791.8555 - mae: 22.4483 - val_loss: 899.5560 - val_mae: 24.3072
# Epoch 54/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 257ms/step - loss: 810.3934 - mae: 22.7433 - val_loss: 846.5854 - val_mae: 23.2148
# Epoch 55/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 135s 263ms/step - loss: 808.5739 - mae: 22.7774 - val_loss: 918.0157 - val_mae: 23.9839
# Epoch 56/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 262ms/step - loss: 787.7356 - mae: 22.4795 - val_loss: 859.0192 - val_mae: 23.3729
# Epoch 57/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 263ms/step - loss: 785.1311 - mae: 22.3651 - val_loss: 851.2307 - val_mae: 23.6890
# Epoch 58/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 257ms/step - loss: 756.1802 - mae: 21.9233 - val_loss: 843.0406 - val_mae: 23.4583
# Epoch 59/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 245ms/step - loss: 779.2242 - mae: 22.2588 - val_loss: 853.8660 - val_mae: 23.8907
# Epoch 60/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 145s 250ms/step - loss: 778.6115 - mae: 22.3407 - val_loss: 820.3382 - val_mae: 22.9925
# Epoch 61/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 245ms/step - loss: 791.8687 - mae: 22.4665 - val_loss: 1302.2118 - val_mae: 27.5734
# Epoch 62/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 253ms/step - loss: 787.5880 - mae: 22.4775 - val_loss: 942.0203 - val_mae: 24.0728
# Epoch 63/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 253ms/step - loss: 762.5486 - mae: 22.0712 - val_loss: 922.9574 - val_mae: 24.0898
# Epoch 64/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 137s 243ms/step - loss: 784.6730 - mae: 22.4088 - val_loss: 1000.5380 - val_mae: 25.2141
# Epoch 65/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 248ms/step - loss: 774.5753 - mae: 22.2237 - val_loss: 1020.5425 - val_mae: 24.9036
# Epoch 66/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 248ms/step - loss: 779.1791 - mae: 22.3114 - val_loss: 805.4369 - val_mae: 23.0200
# Epoch 67/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 151s 265ms/step - loss: 760.2405 - mae: 22.0111 - val_loss: 941.2008 - val_mae: 24.0627
# Epoch 68/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 264ms/step - loss: 777.9813 - mae: 22.2006 - val_loss: 1103.4774 - val_mae: 25.5241
# Epoch 69/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 260ms/step - loss: 746.2756 - mae: 21.8370 - val_loss: 857.4193 - val_mae: 23.9320
# Epoch 70/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 260ms/step - loss: 744.6511 - mae: 21.8281 - val_loss: 1094.3577 - val_mae: 25.7711
# Epoch 71/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 133s 260ms/step - loss: 744.6130 - mae: 21.7150 - val_loss: 817.5489 - val_mae: 23.1072
# Epoch 72/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 255ms/step - loss: 756.0703 - mae: 21.9014 - val_loss: 798.2007 - val_mae: 22.7903
# Epoch 73/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 253ms/step - loss: 764.6387 - mae: 22.0341 - val_loss: 826.1347 - val_mae: 22.9889
# Epoch 74/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 256ms/step - loss: 729.5260 - mae: 21.4621 - val_loss: 901.6434 - val_mae: 23.8455
# Epoch 75/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 257ms/step - loss: 741.7705 - mae: 21.6582 - val_loss: 880.0743 - val_mae: 23.8323
# Epoch 76/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 251ms/step - loss: 765.2413 - mae: 22.1037 - val_loss: 836.3713 - val_mae: 23.1118
# Epoch 77/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 133s 259ms/step - loss: 769.1132 - mae: 22.1418 - val_loss: 1068.9353 - val_mae: 24.9522
# Epoch 78/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 252ms/step - loss: 774.5086 - mae: 22.1351 - val_loss: 887.6563 - val_mae: 23.4167
# Epoch 79/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 253ms/step - loss: 727.2317 - mae: 21.3771 - val_loss: 974.7762 - val_mae: 24.8756
# Epoch 80/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 257ms/step - loss: 760.3015 - mae: 21.9205 - val_loss: 962.5045 - val_mae: 24.1855
# Epoch 81/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 133s 259ms/step - loss: 726.6938 - mae: 21.4902 - val_loss: 779.7869 - val_mae: 22.4123
# Epoch 82/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 255ms/step - loss: 722.5425 - mae: 21.3796 - val_loss: 804.6357 - val_mae: 22.5340
# Epoch 83/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 254ms/step - loss: 782.7409 - mae: 22.3001 - val_loss: 1420.1898 - val_mae: 28.7968
# Epoch 84/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 134s 262ms/step - loss: 798.4999 - mae: 22.5914 - val_loss: 877.5502 - val_mae: 23.5134
# Epoch 85/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 263ms/step - loss: 709.8046 - mae: 21.2036 - val_loss: 933.6049 - val_mae: 23.9078
# Epoch 86/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 251ms/step - loss: 713.8011 - mae: 21.2553 - val_loss: 912.2906 - val_mae: 23.5175
# Epoch 87/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 255ms/step - loss: 735.7307 - mae: 21.5571 - val_loss: 985.3279 - val_mae: 24.0923
# Epoch 88/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 251ms/step - loss: 742.3527 - mae: 21.7124 - val_loss: 842.3897 - val_mae: 23.0685
# Epoch 89/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 252ms/step - loss: 704.6050 - mae: 21.0739 - val_loss: 933.3333 - val_mae: 24.0339
# Epoch 90/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 254ms/step - loss: 721.7043 - mae: 21.4147 - val_loss: 1039.3040 - val_mae: 25.1586
# Epoch 91/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 254ms/step - loss: 705.2985 - mae: 21.0639 - val_loss: 795.8588 - val_mae: 22.7164
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step
# Test RMSE: 28.28
# Test MAE: 22.49
#
# --- Experiment 1 Report ---
# RMSE: 28.28
# MAE: 22.49
# Settings: {'dataset_name': 'FD002', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 2/4 with config: FD002, Scaler: minmax, Seq Length: 50, Piecewise RUL: False, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 138s 253ms/step - loss: 8869.3730 - mae: 75.1376 - val_loss: 4782.3828 - val_mae: 52.5393
# Epoch 2/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 138s 245ms/step - loss: 4219.5464 - mae: 49.9481 - val_loss: 3284.1472 - val_mae: 46.4041
# Epoch 3/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 249ms/step - loss: 3354.8987 - mae: 46.5661 - val_loss: 3279.8638 - val_mae: 46.7125
# Epoch 4/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 246ms/step - loss: 3405.2930 - mae: 47.1226 - val_loss: 3279.3936 - val_mae: 46.6910
# Epoch 5/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 128s 250ms/step - loss: 3408.0281 - mae: 47.0764 - val_loss: 3279.3665 - val_mae: 46.6943
# Epoch 6/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 246ms/step - loss: 3325.0530 - mae: 46.5130 - val_loss: 3283.5271 - val_mae: 46.8446
# Epoch 7/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 257ms/step - loss: 3376.0459 - mae: 46.8666 - val_loss: 3268.6328 - val_mae: 46.3283
# Epoch 8/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 256ms/step - loss: 3359.4429 - mae: 46.6111 - val_loss: 2884.2380 - val_mae: 42.4632
# Epoch 9/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 252ms/step - loss: 3035.3633 - mae: 43.4710 - val_loss: 2923.5176 - val_mae: 42.9864
# Epoch 10/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 250ms/step - loss: 2948.2109 - mae: 42.4022 - val_loss: 2927.2527 - val_mae: 43.1946
# Epoch 11/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 247ms/step - loss: 2981.3518 - mae: 42.8821 - val_loss: 2949.4463 - val_mae: 43.0788
# Epoch 12/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 253ms/step - loss: 2946.9028 - mae: 42.5368 - val_loss: 2845.6616 - val_mae: 42.5218
# Epoch 13/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 257ms/step - loss: 2925.5308 - mae: 42.4417 - val_loss: 2915.4216 - val_mae: 43.3848
# Epoch 14/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 255ms/step - loss: 2918.7441 - mae: 42.1302 - val_loss: 2858.4878 - val_mae: 42.9011
# Epoch 15/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 137s 247ms/step - loss: 2879.6201 - mae: 42.0250 - val_loss: 2752.3027 - val_mae: 41.4151
# Epoch 16/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 254ms/step - loss: 2858.7900 - mae: 41.6868 - val_loss: 2754.3665 - val_mae: 42.1387
# Epoch 17/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 251ms/step - loss: 2837.3728 - mae: 41.6427 - val_loss: 2791.8003 - val_mae: 41.8538
# Epoch 18/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 252ms/step - loss: 2764.6985 - mae: 41.1483 - val_loss: 2702.6455 - val_mae: 40.7629
# Epoch 19/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 2779.0398 - mae: 41.1822 - val_loss: 2722.1128 - val_mae: 41.7947
# Epoch 20/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 251ms/step - loss: 2750.1650 - mae: 40.8671 - val_loss: 2653.8818 - val_mae: 41.1523
# Epoch 21/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 254ms/step - loss: 2705.3918 - mae: 40.3786 - val_loss: 2863.1804 - val_mae: 43.4769
# Epoch 22/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 252ms/step - loss: 2652.1021 - mae: 40.1200 - val_loss: 2514.6157 - val_mae: 39.4947
# Epoch 23/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 2645.5994 - mae: 40.0537 - val_loss: 2600.4192 - val_mae: 40.4935
# Epoch 24/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 252ms/step - loss: 2633.3257 - mae: 39.9577 - val_loss: 2467.5674 - val_mae: 38.3476
# Epoch 25/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 253ms/step - loss: 2504.4109 - mae: 38.8463 - val_loss: 2788.9209 - val_mae: 43.0562
# Epoch 26/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 256ms/step - loss: 2567.8181 - mae: 39.3906 - val_loss: 2446.6106 - val_mae: 38.7270
# Epoch 27/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 2584.2334 - mae: 39.4678 - val_loss: 2421.6580 - val_mae: 38.6059
# Epoch 28/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 130s 254ms/step - loss: 2514.9590 - mae: 38.7706 - val_loss: 2367.9077 - val_mae: 37.8975
# Epoch 29/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 2522.5605 - mae: 38.8581 - val_loss: 2356.1663 - val_mae: 38.8563
# Epoch 30/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 257ms/step - loss: 2441.0952 - mae: 38.0991 - val_loss: 2321.3049 - val_mae: 38.2984
# Epoch 31/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 255ms/step - loss: 2402.7500 - mae: 37.9191 - val_loss: 2425.7070 - val_mae: 39.8131
# Epoch 32/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 254ms/step - loss: 2398.5354 - mae: 37.7955 - val_loss: 2274.7903 - val_mae: 37.8798
# Epoch 33/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 248ms/step - loss: 2373.4688 - mae: 37.4280 - val_loss: 2310.5610 - val_mae: 37.5030
# Epoch 34/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 124s 243ms/step - loss: 2291.0933 - mae: 36.5879 - val_loss: 2295.1780 - val_mae: 37.4011
# Epoch 35/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 242ms/step - loss: 2225.5144 - mae: 36.0543 - val_loss: 2441.7002 - val_mae: 37.8290
# Epoch 36/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 244ms/step - loss: 2265.5322 - mae: 36.3650 - val_loss: 2233.2329 - val_mae: 36.5573
# Epoch 37/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 243ms/step - loss: 2180.3970 - mae: 35.7605 - val_loss: 2659.0022 - val_mae: 42.4831
# Epoch 38/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 246ms/step - loss: 2264.2354 - mae: 36.4872 - val_loss: 2223.5872 - val_mae: 38.0489
# Epoch 39/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 249ms/step - loss: 2186.7896 - mae: 35.8661 - val_loss: 2073.6611 - val_mae: 35.6885
# Epoch 40/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 148s 260ms/step - loss: 2140.0481 - mae: 35.3200 - val_loss: 2627.8716 - val_mae: 41.9903
# Epoch 41/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 134s 245ms/step - loss: 2122.2275 - mae: 35.1015 - val_loss: 2133.2925 - val_mae: 37.0015
# Epoch 42/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 132s 257ms/step - loss: 2125.5371 - mae: 34.9881 - val_loss: 2433.4812 - val_mae: 36.7514
# Epoch 43/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 131s 255ms/step - loss: 2065.3152 - mae: 34.4179 - val_loss: 2157.9133 - val_mae: 36.7174
# Epoch 44/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 245ms/step - loss: 2011.1545 - mae: 33.9700 - val_loss: 2206.5486 - val_mae: 35.5228
# Epoch 45/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 147s 255ms/step - loss: 2019.7207 - mae: 33.8570 - val_loss: 2060.0195 - val_mae: 36.6372
# Epoch 46/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 251ms/step - loss: 1986.2860 - mae: 33.6520 - val_loss: 1850.7091 - val_mae: 33.3441
# Epoch 47/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 253ms/step - loss: 1977.3926 - mae: 33.5403 - val_loss: 2275.9116 - val_mae: 35.3017
# Epoch 48/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 250ms/step - loss: 1933.1901 - mae: 33.1669 - val_loss: 1807.1874 - val_mae: 33.6807
# Epoch 49/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 249ms/step - loss: 1949.4106 - mae: 33.3360 - val_loss: 1798.8407 - val_mae: 33.6169
# Epoch 50/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 246ms/step - loss: 1901.5128 - mae: 32.7015 - val_loss: 2002.2274 - val_mae: 33.7732
# Epoch 51/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 243ms/step - loss: 1885.4603 - mae: 32.7404 - val_loss: 1753.7671 - val_mae: 33.0545
# Epoch 52/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 151s 262ms/step - loss: 1849.2476 - mae: 32.3996 - val_loss: 1940.1343 - val_mae: 32.7184
# Epoch 53/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 257ms/step - loss: 1818.3473 - mae: 32.0657 - val_loss: 1856.9440 - val_mae: 32.8716
# Epoch 54/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 129s 251ms/step - loss: 1804.6505 - mae: 31.8967 - val_loss: 1806.4476 - val_mae: 33.5231
# Epoch 55/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 148s 264ms/step - loss: 1803.1134 - mae: 31.8691 - val_loss: 1765.0212 - val_mae: 33.4086
# Epoch 56/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 138s 257ms/step - loss: 1807.4216 - mae: 31.8352 - val_loss: 1765.1931 - val_mae: 33.5941
# Epoch 57/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 133s 258ms/step - loss: 1802.1392 - mae: 31.8700 - val_loss: 1716.5403 - val_mae: 32.5668
# Epoch 58/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 261ms/step - loss: 1746.3533 - mae: 31.3509 - val_loss: 1796.7900 - val_mae: 34.0727
# Epoch 59/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 265ms/step - loss: 1806.6381 - mae: 31.8172 - val_loss: 1731.6635 - val_mae: 33.0416
# Epoch 60/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 138s 258ms/step - loss: 1692.4408 - mae: 30.8393 - val_loss: 1596.1415 - val_mae: 30.7562
# Epoch 61/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 134s 243ms/step - loss: 1798.2878 - mae: 31.8531 - val_loss: 1814.5693 - val_mae: 33.4449
# Epoch 62/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 126s 245ms/step - loss: 1778.6495 - mae: 31.6422 - val_loss: 1718.0975 - val_mae: 31.2640
# Epoch 63/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 127s 247ms/step - loss: 1702.3248 - mae: 30.7541 - val_loss: 1808.4568 - val_mae: 32.1096
# Epoch 64/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 124s 242ms/step - loss: 1740.2042 - mae: 31.1977 - val_loss: 1647.4073 - val_mae: 31.9000
# Epoch 65/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 236ms/step - loss: 1730.7024 - mae: 31.1368 - val_loss: 2089.0178 - val_mae: 36.8982
# Epoch 66/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 240ms/step - loss: 1712.1050 - mae: 31.0050 - val_loss: 1677.5702 - val_mae: 31.1710
# Epoch 67/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 146s 247ms/step - loss: 1765.1923 - mae: 31.4623 - val_loss: 1620.6880 - val_mae: 31.6073
# Epoch 68/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 134s 262ms/step - loss: 1659.8479 - mae: 30.4512 - val_loss: 1749.1669 - val_mae: 33.2364
# Epoch 69/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 271ms/step - loss: 1698.9402 - mae: 30.7393 - val_loss: 2773.5459 - val_mae: 43.7311
# Epoch 70/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 270ms/step - loss: 1729.5396 - mae: 31.1406 - val_loss: 1631.0883 - val_mae: 31.4469
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 29s 42ms/step
# Test RMSE: 49.29
# Test MAE: 38.02
#
# --- Experiment 2 Report ---
# RMSE: 49.29
# MAE: 38.02
# Settings: {'dataset_name': 'FD002', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': False, 'max_rul_cap': 125, 'feature_set': ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 3/4 with config: FD002, Scaler: minmax, Seq Length: 60, Piecewise RUL: True, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 174s 341ms/step - loss: 5566.6885 - mae: 63.1287 - val_loss: 2584.9673 - val_mae: 42.3408
# Epoch 2/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 199s 334ms/step - loss: 2178.9233 - mae: 39.6132 - val_loss: 1693.0950 - val_mae: 36.1531
# Epoch 3/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 206s 342ms/step - loss: 1689.2024 - mae: 36.0656 - val_loss: 1693.2623 - val_mae: 36.1523
# Epoch 4/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 341ms/step - loss: 1698.3663 - mae: 36.1880 - val_loss: 1692.8679 - val_mae: 36.1498
# Epoch 5/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 188s 312ms/step - loss: 1692.6016 - mae: 36.1520 - val_loss: 1694.8290 - val_mae: 36.1606
# Epoch 6/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 216s 342ms/step - loss: 1682.5181 - mae: 35.9669 - val_loss: 1693.6052 - val_mae: 36.1531
# Epoch 7/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 188s 313ms/step - loss: 1689.0520 - mae: 36.0904 - val_loss: 1693.5945 - val_mae: 36.1502
# Epoch 8/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 198s 304ms/step - loss: 1679.3075 - mae: 35.9205 - val_loss: 1472.7979 - val_mae: 33.1045
# Epoch 9/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 218s 337ms/step - loss: 1512.6418 - mae: 33.5070 - val_loss: 1449.2737 - val_mae: 32.7520
# Epoch 10/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 193s 318ms/step - loss: 1473.0547 - mae: 32.8835 - val_loss: 1447.0870 - val_mae: 32.5413
# Epoch 11/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 143s 297ms/step - loss: 1478.7306 - mae: 33.0363 - val_loss: 1425.4573 - val_mae: 32.4010
# Epoch 12/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 150s 311ms/step - loss: 1436.9188 - mae: 32.3625 - val_loss: 1463.9797 - val_mae: 32.3963
# Epoch 13/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 208s 325ms/step - loss: 1440.4460 - mae: 32.4562 - val_loss: 1345.6667 - val_mae: 31.4849
# Epoch 14/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 147s 306ms/step - loss: 1392.4873 - mae: 31.6942 - val_loss: 1371.0610 - val_mae: 31.4092
# Epoch 15/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 306ms/step - loss: 1342.7924 - mae: 31.0582 - val_loss: 1467.5133 - val_mae: 32.7379
# Epoch 16/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 217s 336ms/step - loss: 1438.6339 - mae: 32.3451 - val_loss: 1377.3351 - val_mae: 30.8837
# Epoch 17/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 190s 312ms/step - loss: 1355.7137 - mae: 31.0879 - val_loss: 1309.3710 - val_mae: 30.3849
# Epoch 18/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 196s 299ms/step - loss: 1247.8629 - mae: 29.6430 - val_loss: 1190.8491 - val_mae: 29.3294
# Epoch 19/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 298ms/step - loss: 1186.6672 - mae: 28.9025 - val_loss: 1101.5216 - val_mae: 27.8741
# Epoch 20/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 152s 316ms/step - loss: 1151.2257 - mae: 28.3454 - val_loss: 1097.7473 - val_mae: 27.6663
# Epoch 21/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 197s 305ms/step - loss: 1141.0963 - mae: 28.1863 - val_loss: 1122.7819 - val_mae: 27.6728
# Epoch 22/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 217s 337ms/step - loss: 1078.4333 - mae: 27.3220 - val_loss: 1231.9034 - val_mae: 28.7675
# Epoch 23/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 204s 342ms/step - loss: 1050.4862 - mae: 26.9673 - val_loss: 1117.1791 - val_mae: 27.4215
# Epoch 24/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 183s 304ms/step - loss: 1047.9136 - mae: 26.8625 - val_loss: 1017.8278 - val_mae: 26.9536
# Epoch 25/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 149s 310ms/step - loss: 1015.9051 - mae: 26.4943 - val_loss: 1000.7449 - val_mae: 26.1422
# Epoch 26/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 207s 321ms/step - loss: 996.2514 - mae: 26.0170 - val_loss: 1038.2717 - val_mae: 26.1924
# Epoch 27/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 165s 344ms/step - loss: 960.8784 - mae: 25.4080 - val_loss: 949.6819 - val_mae: 25.4378
# Epoch 28/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 197s 333ms/step - loss: 919.5878 - mae: 24.9668 - val_loss: 977.7263 - val_mae: 25.6461
# Epoch 29/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 156s 324ms/step - loss: 892.0143 - mae: 24.4751 - val_loss: 922.7287 - val_mae: 25.0061
# Epoch 30/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - loss: 928.9112 - mae: 25.0085 - val_loss: 907.1421 - val_mae: 25.0280
# Epoch 31/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 213s 333ms/step - loss: 892.8863 - mae: 24.5233 - val_loss: 998.1099 - val_mae: 25.6997
# Epoch 32/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 198s 326ms/step - loss: 901.0335 - mae: 24.6607 - val_loss: 892.2686 - val_mae: 24.7501
# Epoch 33/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 153s 319ms/step - loss: 883.8167 - mae: 24.3992 - val_loss: 1038.7345 - val_mae: 25.5597
# Epoch 34/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 196s 307ms/step - loss: 850.0826 - mae: 23.7443 - val_loss: 866.9187 - val_mae: 24.2833
# Epoch 35/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 195s 292ms/step - loss: 858.4809 - mae: 23.8097 - val_loss: 948.5482 - val_mae: 25.2860
# Epoch 36/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 297ms/step - loss: 870.7590 - mae: 24.1415 - val_loss: 943.9782 - val_mae: 25.0333
# Epoch 37/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 138s 286ms/step - loss: 832.4758 - mae: 23.5389 - val_loss: 1094.6625 - val_mae: 26.8750
# Epoch 38/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 139s 288ms/step - loss: 865.0699 - mae: 24.0329 - val_loss: 918.8802 - val_mae: 24.7765
# Epoch 39/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 150s 313ms/step - loss: 851.9872 - mae: 23.6923 - val_loss: 1157.2338 - val_mae: 26.4160
# Epoch 40/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 193s 293ms/step - loss: 864.6336 - mae: 23.8204 - val_loss: 865.2892 - val_mae: 23.9777
# Epoch 41/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 143s 295ms/step - loss: 792.4963 - mae: 22.8323 - val_loss: 1626.4120 - val_mae: 31.8284
# Epoch 42/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 293ms/step - loss: 874.3331 - mae: 23.9681 - val_loss: 1037.2720 - val_mae: 25.4520
# Epoch 43/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 139s 289ms/step - loss: 839.0995 - mae: 23.5124 - val_loss: 798.0889 - val_mae: 23.2531
# Epoch 44/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 142s 296ms/step - loss: 827.8630 - mae: 23.2833 - val_loss: 799.7794 - val_mae: 22.9096
# Epoch 45/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 300ms/step - loss: 781.5745 - mae: 22.5960 - val_loss: 1443.4520 - val_mae: 29.1770
# Epoch 46/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 204s 303ms/step - loss: 790.9039 - mae: 22.7914 - val_loss: 838.5315 - val_mae: 23.2673
# Epoch 47/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 300ms/step - loss: 778.9612 - mae: 22.5769 - val_loss: 952.8477 - val_mae: 24.5518
# Epoch 48/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 215s 326ms/step - loss: 789.5441 - mae: 22.8369 - val_loss: 825.9519 - val_mae: 23.0389
# Epoch 49/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 324ms/step - loss: 829.1230 - mae: 23.2829 - val_loss: 1031.4159 - val_mae: 25.0788
# Epoch 50/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 189s 297ms/step - loss: 819.2914 - mae: 23.3000 - val_loss: 788.6179 - val_mae: 22.7896
# Epoch 51/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 205s 305ms/step - loss: 827.7023 - mae: 23.2996 - val_loss: 1071.8101 - val_mae: 26.2135
# Epoch 52/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 199s 299ms/step - loss: 792.4810 - mae: 22.7229 - val_loss: 870.0785 - val_mae: 23.8267
# Epoch 53/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 198s 291ms/step - loss: 749.3387 - mae: 22.1451 - val_loss: 1145.5283 - val_mae: 26.8721
# Epoch 54/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 146s 298ms/step - loss: 806.1863 - mae: 22.8663 - val_loss: 789.0101 - val_mae: 23.0990
# Epoch 55/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 212s 320ms/step - loss: 784.6353 - mae: 22.6945 - val_loss: 939.7212 - val_mae: 24.1095
# Epoch 56/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 196s 308ms/step - loss: 767.1841 - mae: 22.4453 - val_loss: 1084.6373 - val_mae: 25.5205
# Epoch 57/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 200s 305ms/step - loss: 762.0348 - mae: 22.1992 - val_loss: 947.9443 - val_mae: 24.3597
# Epoch 58/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 203s 307ms/step - loss: 760.5237 - mae: 22.2909 - val_loss: 868.9572 - val_mae: 23.8859
# Epoch 59/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 305ms/step - loss: 757.2888 - mae: 22.1829 - val_loss: 989.1633 - val_mae: 24.6194
# Epoch 60/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 303ms/step - loss: 753.5360 - mae: 22.0495 - val_loss: 929.2614 - val_mae: 23.6656
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 28s 46ms/step
# Test RMSE: 26.43
# Test MAE: 21.81
#
# --- Experiment 3 Report ---
# RMSE: 26.43
# MAE: 21.81
# Settings: {'dataset_name': 'FD002', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 4/4 with config: FD002, Scaler: minmax, Seq Length: 60, Piecewise RUL: False, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 158s 308ms/step - loss: 7979.2949 - mae: 70.6040 - val_loss: 4260.0376 - val_mae: 49.2875
# Epoch 2/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 146s 303ms/step - loss: 3788.1667 - mae: 46.8836 - val_loss: 3035.4277 - val_mae: 44.5199
# Epoch 3/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 212s 325ms/step - loss: 3096.3481 - mae: 44.7163 - val_loss: 3034.9128 - val_mae: 44.8453
# Epoch 4/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 207s 335ms/step - loss: 3123.6465 - mae: 44.7590 - val_loss: 3033.9910 - val_mae: 44.8018
# Epoch 5/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 200s 331ms/step - loss: 3119.0984 - mae: 44.7349 - val_loss: 3037.3164 - val_mae: 44.9326
# Epoch 6/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 141s 294ms/step - loss: 3104.0730 - mae: 44.6688 - val_loss: 3034.5027 - val_mae: 44.8402
# Epoch 7/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 143s 297ms/step - loss: 3116.4468 - mae: 44.9359 - val_loss: 3019.9854 - val_mae: 44.5303
# Epoch 8/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 205s 303ms/step - loss: 3074.4727 - mae: 44.6655 - val_loss: 3034.0430 - val_mae: 44.8986
# Epoch 9/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 147s 305ms/step - loss: 3055.2825 - mae: 44.2231 - val_loss: 2782.7219 - val_mae: 42.1225
# Epoch 10/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 304ms/step - loss: 2806.9814 - mae: 41.4700 - val_loss: 2693.7769 - val_mae: 41.3301
# Epoch 11/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 214s 329ms/step - loss: 2824.9854 - mae: 41.4810 - val_loss: 2791.7505 - val_mae: 41.9282
# Epoch 12/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 191s 306ms/step - loss: 2709.0010 - mae: 40.6993 - val_loss: 2754.0078 - val_mae: 42.2708
# Epoch 13/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 204s 311ms/step - loss: 2749.7800 - mae: 40.9362 - val_loss: 2589.8533 - val_mae: 40.4783
# Epoch 14/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 212s 332ms/step - loss: 2728.6672 - mae: 40.7099 - val_loss: 2627.6431 - val_mae: 40.0616
# Epoch 15/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 147s 305ms/step - loss: 2710.4604 - mae: 40.6820 - val_loss: 2679.0381 - val_mae: 40.7390
# Epoch 16/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 303ms/step - loss: 2685.8035 - mae: 40.2829 - val_loss: 2518.4890 - val_mae: 39.8609
# Epoch 17/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 214s 327ms/step - loss: 2652.5471 - mae: 40.1449 - val_loss: 2560.3250 - val_mae: 39.0022
# Epoch 18/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 201s 325ms/step - loss: 2613.9512 - mae: 39.7839 - val_loss: 2627.1096 - val_mae: 41.1760
# Epoch 19/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 143s 298ms/step - loss: 2543.6116 - mae: 39.3120 - val_loss: 2468.3098 - val_mae: 39.6570
# Epoch 20/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 150s 313ms/step - loss: 2535.9282 - mae: 39.1576 - val_loss: 2611.3076 - val_mae: 41.1665
# Epoch 21/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 145s 301ms/step - loss: 2536.6172 - mae: 39.2195 - val_loss: 2453.3755 - val_mae: 39.6008
# Epoch 22/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 212s 322ms/step - loss: 2555.2207 - mae: 39.2756 - val_loss: 2350.3813 - val_mae: 37.7810
# Epoch 23/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 203s 324ms/step - loss: 2413.9680 - mae: 38.0255 - val_loss: 2356.4905 - val_mae: 38.8831
# Epoch 24/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 193s 306ms/step - loss: 2488.0864 - mae: 38.7159 - val_loss: 2501.8542 - val_mae: 38.0200
# Epoch 25/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 299ms/step - loss: 2439.4597 - mae: 38.2624 - val_loss: 2359.1680 - val_mae: 38.7747
# Epoch 26/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 204s 305ms/step - loss: 2399.9460 - mae: 38.0670 - val_loss: 2436.6619 - val_mae: 39.6734
# Epoch 27/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 211s 324ms/step - loss: 2384.5684 - mae: 37.9594 - val_loss: 2278.4612 - val_mae: 37.6275
# Epoch 28/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 145s 301ms/step - loss: 2331.7087 - mae: 37.4947 - val_loss: 2309.9243 - val_mae: 38.8112
# Epoch 29/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 157s 326ms/step - loss: 2321.1533 - mae: 37.2974 - val_loss: 2510.1726 - val_mae: 38.2389
# Epoch 30/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 160s 332ms/step - loss: 2324.4758 - mae: 37.2617 - val_loss: 2252.9246 - val_mae: 38.0784
# Epoch 31/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 187s 301ms/step - loss: 2259.9331 - mae: 36.7151 - val_loss: 2451.1155 - val_mae: 40.1199
# Epoch 32/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 302ms/step - loss: 2256.6362 - mae: 36.7343 - val_loss: 2359.5203 - val_mae: 39.3713
# Epoch 33/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 195s 288ms/step - loss: 2223.2249 - mae: 36.6062 - val_loss: 2490.1033 - val_mae: 37.9674
# Epoch 34/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 141s 293ms/step - loss: 2171.7039 - mae: 36.0169 - val_loss: 2200.1699 - val_mae: 36.4227
# Epoch 35/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 298ms/step - loss: 2241.7888 - mae: 36.3765 - val_loss: 2177.1055 - val_mae: 36.1485
# Epoch 36/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 145s 301ms/step - loss: 2143.5435 - mae: 35.5325 - val_loss: 2141.0901 - val_mae: 36.0331
# Epoch 37/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 157s 326ms/step - loss: 2106.4629 - mae: 35.3647 - val_loss: 2092.1702 - val_mae: 36.0291
# Epoch 38/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 199s 321ms/step - loss: 2086.8103 - mae: 35.1048 - val_loss: 2070.0681 - val_mae: 35.7531
# Epoch 39/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 189s 294ms/step - loss: 2156.2896 - mae: 35.6137 - val_loss: 2168.8420 - val_mae: 35.6462
# Epoch 40/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 157s 326ms/step - loss: 2076.4592 - mae: 35.0125 - val_loss: 1922.5471 - val_mae: 34.8664
# Epoch 41/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 192s 306ms/step - loss: 2062.8179 - mae: 34.8946 - val_loss: 2477.6309 - val_mae: 40.4080
# Epoch 42/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 198s 299ms/step - loss: 2035.5793 - mae: 34.6355 - val_loss: 2250.4431 - val_mae: 35.9828
# Epoch 43/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 154s 319ms/step - loss: 1973.9363 - mae: 33.8310 - val_loss: 1882.7577 - val_mae: 33.8942
# Epoch 44/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 187s 289ms/step - loss: 1934.4738 - mae: 33.7165 - val_loss: 2171.2573 - val_mae: 35.3775
# Epoch 45/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 155s 316ms/step - loss: 1934.3276 - mae: 33.4795 - val_loss: 1828.3282 - val_mae: 33.7803
# Epoch 46/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 206s 325ms/step - loss: 1834.3784 - mae: 32.5210 - val_loss: 1994.2693 - val_mae: 35.6932
# Epoch 47/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 190s 301ms/step - loss: 1855.0135 - mae: 32.6992 - val_loss: 1833.1035 - val_mae: 33.7674
# Epoch 48/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 301ms/step - loss: 1931.4778 - mae: 33.2474 - val_loss: 2046.7783 - val_mae: 36.4461
# Epoch 49/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 301ms/step - loss: 1815.5454 - mae: 32.4347 - val_loss: 1759.4442 - val_mae: 32.6335
# Epoch 50/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 142s 296ms/step - loss: 1810.5417 - mae: 32.2760 - val_loss: 2056.7876 - val_mae: 36.4920
# Epoch 51/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 212s 317ms/step - loss: 1793.1250 - mae: 32.1554 - val_loss: 2573.7075 - val_mae: 40.7474
# Epoch 52/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 144s 299ms/step - loss: 1937.7885 - mae: 33.5357 - val_loss: 2059.6167 - val_mae: 36.4006
# Epoch 53/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 202s 299ms/step - loss: 1765.6958 - mae: 31.8504 - val_loss: 1722.7354 - val_mae: 32.4873
# Epoch 54/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 199s 292ms/step - loss: 1778.4047 - mae: 31.9457 - val_loss: 1817.3322 - val_mae: 33.2522
# Epoch 55/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 143s 294ms/step - loss: 1702.2566 - mae: 31.2380 - val_loss: 1683.2776 - val_mae: 31.6130
# Epoch 56/100
# 354/481 ━━━━━━━━━━━━━━━━━━━━ 34s 275ms/step - loss: 1729.5596 - mae: 31.4459
