# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/PMTese/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install python-docx

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow import keras
from tensorflow.keras import layers

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Configs

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_all = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
]

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_FD001_Corr = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD001_Boruta=[
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Corr = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Boruta = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
FD003_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD004_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD003_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD004_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_FD003_Corr = [
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD003_Boruta=[
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr_1_2 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr_3_4 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta_1_2 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta_3_4 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
def run_transformer_experiment(config):

    dataset_name = config["dataset_name"]
    scaler_type = config["scaler_type"]
    seq_length = config["seq_length"]
    use_piecewise_rul = config["use_piecewise_rul"]
    max_rul_cap = config["max_rul_cap"]
    useful_sensor_cols = config["feature_set"]
    batch_size = config["batch_size"]
    epochs = config["epochs"]
    lstm_units = config["lstm_units"]
    dropout_rate = config["dropout_rate"]
    loss_function = config["loss_function"]
    head_size= config["head_size"]
    num_heads=4
    ff_dim=128
    num_transformer_blocks=2
    mlp_units=[128]
    dropout=0.1
    mlp_dropout=0.1
    embedding_dim=64

    column_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor{i}' for i in range(1, 22)]
    train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
    test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
    rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)

    train_data.columns = column_names
    test_data.columns = column_names
    rul_data.columns = ['RUL']
    rul_data['id'] = range(1, len(rul_data) + 1)

    max_cycle = train_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'cycle_max'})
    train_data = train_data.merge(max_cycle, on='id')
    train_data['RUL'] = train_data['cycle_max'] - train_data['cycle']
    train_data.drop(columns=['cycle_max'], inplace=True)

    max_cycle_test = test_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
    test_data = test_data.merge(max_cycle_test, on='id')
    test_data = test_data.merge(rul_data, on='id')
    test_data['RUL'] = test_data['RUL'] + test_data['max_cycle'] - test_data['cycle']
    test_data.drop(columns=['max_cycle'], inplace=True)

    if use_piecewise_rul:
        train_data['RUL'] = train_data['RUL'].clip(upper=max_rul_cap)
        test_data['RUL'] = test_data['RUL'].clip(upper=max_rul_cap)

    train_data = train_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]
    test_data = test_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]

    scaler = MinMaxScaler() if scaler_type == 'minmax' else StandardScaler()
    train_data[useful_sensor_cols] = scaler.fit_transform(train_data[useful_sensor_cols])
    test_data[useful_sensor_cols] = scaler.transform(test_data[useful_sensor_cols])

    def create_sequences(data, sequence_length):
        sequences, labels = [], []
        for engine_id in data['id'].unique():
            engine_data = data[data['id'] == engine_id]
            X = engine_data[useful_sensor_cols].values
            y = engine_data['RUL'].values
            for i in range(len(X) - sequence_length + 1):
                sequences.append(X[i:i+sequence_length])
                labels.append(y[i+sequence_length-1])
        return np.array(sequences), np.array(labels)

    X_train, y_train = create_sequences(train_data, seq_length)
    X_test, y_test = create_sequences(test_data, seq_length)

    def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
        # Attention block
        attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
        attn_output = layers.Dropout(dropout)(attn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)  # Add & Norm

        # Feed Forward block
        ff_output = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        ff_output = layers.Dropout(dropout)(ff_output)
        ff_output = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ff_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + ff_output)  # Add & Norm

        return x


    def build_model(input_shape):
        inputs = keras.Input(shape=input_shape)
        x = inputs

        # https://www.tensorflow.org/tutorials/structured_data/time_series
        x = layers.Dense(embedding_dim)(inputs)

        for _ in range(num_transformer_blocks):
            x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D()(x)
        for units in mlp_units:
            x = layers.Dense(units, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(1)(x)  # Predict RUL
        return keras.Model(inputs, outputs)

    model = build_model(X_train.shape[1:])
    model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["mae"])

    early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=64,
        callbacks=[early_stopping]
    )

    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test RMSE: {rmse:.2f}")
    print(f"Test MAE: {mae:.2f}")

    return model, y_pred, rmse, mae

# %%
def compare_datasets(test_configs):
    results = []
    num_configs = len(test_configs)
    for i, config in enumerate(test_configs):
        print(f"Running experiment {i + 1}/{num_configs} with config: {config['dataset_name']}, Scaler: {config['scaler_type']}, Seq Length: {config['seq_length']}, Piecewise RUL: {config['use_piecewise_rul']}, Features: {', '.join(config['feature_set'])}")
        model, y_pred, rmse, mae = run_transformer_experiment(config)
        result = {
            'dataset': config['dataset_name'],
            'rmse': rmse,
            'mae': mae,
            'config': config
        }
        results.append(result)
        print(f"\n--- Experiment {i + 1} Report ---")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")
        print(f"Settings: {config}")
    return results

# %%
from docx import Document

def save_experiment_to_docx(results_list, output_path="/content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_transformer_20250904_FD004_Corr_1_2.docx"):
    doc = Document()
    doc.add_heading("Transformer RUL Prediction Experiment Results", level=1)

    for i, res in enumerate(results_list):
        doc.add_heading(f"Experiment {i + 1} – Dataset: {res['dataset']}", level=2)
        doc.add_paragraph(f"RMSE: {res['rmse']:.2f}")
        doc.add_paragraph(f"MAE: {res['mae']:.2f}")
        doc.add_paragraph("Settings Used:")
        for key, value in res['config'].items():
            doc.add_paragraph(f"- {key}: {value}", style='List Bullet')

        doc.add_paragraph("")  # Blank line between experiments

    doc.save(output_path)
    print(f"✅ Document saved to {output_path}")

# %%
results = compare_datasets(test_configs_FD004_Corr_1_2)
save_experiment_to_docx(results)

# Create summary table
summary_df = pd.DataFrame([
    {
        'Dataset': r['dataset'],
        'RMSE': r['rmse'],
        'MAE': r['mae'],
        'Scaler': r['config']['scaler_type'],
        'Seq Length': r['config']['seq_length'],
        'Piecewise RUL': r['config']['use_piecewise_rul'],
        'Features': ', '.join(r['config']['feature_set'])
    }
    for r in results
])

display(summary_df)
# Out:
# Running experiment 1/2 with config: FD004, Scaler: minmax, Seq Length: 50, Piecewise RUL: True, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# ...
