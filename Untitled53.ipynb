# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/PMTese/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install python-docx

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Configs

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_all = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
]

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_FD001_Corr = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD001_Boruta=[
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Corr = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD002_Boruta = [
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
FD003_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD004_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD003_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD004_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_FD003_Corr = [
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD003_Boruta=[
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr_1_2 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr_3_4 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Corr = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta_1_2 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta_3_4 = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

test_configs_FD004_Boruta = [
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
def run_transformer_experiment(config):

    dataset_name = config["dataset_name"]
    scaler_type = config["scaler_type"]
    seq_length = config["seq_length"]
    use_piecewise_rul = config["use_piecewise_rul"]
    max_rul_cap = config["max_rul_cap"]
    useful_sensor_cols = config["feature_set"]
    batch_size = config["batch_size"]
    epochs = config["epochs"]
    lstm_units = config["lstm_units"]
    dropout_rate = config["dropout_rate"]
    loss_function = config["loss_function"]
    head_size= config["head_size"]
    num_heads=4
    ff_dim=128
    num_transformer_blocks=2
    mlp_units=[128]
    dropout=0.1
    mlp_dropout=0.1
    embedding_dim=64

    column_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor{i}' for i in range(1, 22)]
    train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
    test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
    rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)

    train_data.columns = column_names
    test_data.columns = column_names
    rul_data.columns = ['RUL']
    rul_data['id'] = range(1, len(rul_data) + 1)

    max_cycle = train_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'cycle_max'})
    train_data = train_data.merge(max_cycle, on='id')
    train_data['RUL'] = train_data['cycle_max'] - train_data['cycle']
    train_data.drop(columns=['cycle_max'], inplace=True)

    max_cycle_test = test_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
    test_data = test_data.merge(max_cycle_test, on='id')
    test_data = test_data.merge(rul_data, on='id')
    test_data['RUL'] = test_data['RUL'] + test_data['max_cycle'] - test_data['cycle']
    test_data.drop(columns=['max_cycle'], inplace=True)

    if use_piecewise_rul:
        train_data['RUL'] = train_data['RUL'].clip(upper=max_rul_cap)
        test_data['RUL'] = test_data['RUL'].clip(upper=max_rul_cap)

    train_data = train_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]
    test_data = test_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]

    scaler = MinMaxScaler() if scaler_type == 'minmax' else StandardScaler()
    train_data[useful_sensor_cols] = scaler.fit_transform(train_data[useful_sensor_cols])
    test_data[useful_sensor_cols] = scaler.transform(test_data[useful_sensor_cols])

    def create_sequences(data, sequence_length):
        sequences, labels = [], []
        for engine_id in data['id'].unique():
            engine_data = data[data['id'] == engine_id]
            X = engine_data[useful_sensor_cols].values
            y = engine_data['RUL'].values
            for i in range(len(X) - sequence_length + 1):
                sequences.append(X[i:i+sequence_length])
                labels.append(y[i+sequence_length-1])
        return np.array(sequences), np.array(labels)

    X_train, y_train = create_sequences(train_data, seq_length)
    X_test, y_test = create_sequences(test_data, seq_length)

    def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
        # Attention block
        attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
        attn_output = layers.Dropout(dropout)(attn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)  # Add & Norm

        # Feed Forward block
        ff_output = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        ff_output = layers.Dropout(dropout)(ff_output)
        ff_output = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ff_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + ff_output)  # Add & Norm

        return x


    def build_model(input_shape):
        inputs = keras.Input(shape=input_shape)
        x = inputs

        # https://www.tensorflow.org/tutorials/structured_data/time_series
        x = layers.Dense(embedding_dim)(inputs)

        for _ in range(num_transformer_blocks):
            x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D()(x)
        for units in mlp_units:
            x = layers.Dense(units, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(1)(x)  # Predict RUL
        return keras.Model(inputs, outputs)

    model = build_model(X_train.shape[1:])
    model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["mae"])

    early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=64,
        callbacks=[early_stopping]
    )

    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test RMSE: {rmse:.2f}")
    print(f"Test MAE: {mae:.2f}")

    return model, y_pred, rmse, mae

# %%
def compare_datasets(test_configs):
    results = []
    num_configs = len(test_configs)
    for i, config in enumerate(test_configs):
        print(f"Running experiment {i + 1}/{num_configs} with config: {config['dataset_name']}, Scaler: {config['scaler_type']}, Seq Length: {config['seq_length']}, Piecewise RUL: {config['use_piecewise_rul']}, Features: {', '.join(config['feature_set'])}")
        model, y_pred, rmse, mae = run_transformer_experiment(config)
        result = {
            'dataset': config['dataset_name'],
            'rmse': rmse,
            'mae': mae,
            'config': config
        }
        results.append(result)
        print(f"\n--- Experiment {i + 1} Report ---")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")
        print(f"Settings: {config}")
    return results

# %%
from docx import Document

def save_experiment_to_docx(results_list, output_path="/content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_transformer_20250907_FD004_Corr_4.docx"):
    doc = Document()
    doc.add_heading("Transformer RUL Prediction Experiment Results", level=1)

    for i, res in enumerate(results_list):
        doc.add_heading(f"Experiment {i + 1} – Dataset: {res['dataset']}", level=2)
        doc.add_paragraph(f"RMSE: {res['rmse']:.2f}")
        doc.add_paragraph(f"MAE: {res['mae']:.2f}")
        doc.add_paragraph("Settings Used:")
        for key, value in res['config'].items():
            doc.add_paragraph(f"- {key}: {value}", style='List Bullet')

        doc.add_paragraph("")  # Blank line between experiments

    doc.save(output_path)
    print(f"✅ Document saved to {output_path}")

# %%
results = compare_datasets(test_configs_FD004_Corr_3_4)
save_experiment_to_docx(results)

# Create summary table
summary_df = pd.DataFrame([
    {
        'Dataset': r['dataset'],
        'RMSE': r['rmse'],
        'MAE': r['mae'],
        'Scaler': r['config']['scaler_type'],
        'Seq Length': r['config']['seq_length'],
        'Piecewise RUL': r['config']['use_piecewise_rul'],
        'Features': ', '.join(r['config']['feature_set'])
    }
    for r in results
])

display(summary_df)
# Out:
# Running experiment 1/2 with config: FD004, Scaler: minmax, Seq Length: 60, Piecewise RUL: True, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 192s 302ms/step - loss: 6906.5278 - mae: 72.4002 - val_loss: 2951.9939 - val_mae: 47.2054
# Epoch 2/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 200s 300ms/step - loss: 2407.3567 - mae: 43.3330 - val_loss: 1776.3826 - val_mae: 37.6252
# Epoch 3/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 192s 283ms/step - loss: 1783.4155 - mae: 37.6082 - val_loss: 1777.7609 - val_mae: 37.4593
# Epoch 4/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 205s 288ms/step - loss: 1790.6633 - mae: 37.6351 - val_loss: 1775.5177 - val_mae: 37.5429
# Epoch 5/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 210s 301ms/step - loss: 1744.2723 - mae: 36.9959 - val_loss: 1330.2512 - val_mae: 31.1218
# Epoch 6/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 193s 285ms/step - loss: 1291.6742 - mae: 30.2440 - val_loss: 1319.6130 - val_mae: 30.3654
# Epoch 7/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 173s 297ms/step - loss: 1251.7900 - mae: 29.5098 - val_loss: 1350.9829 - val_mae: 30.8250
# Epoch 8/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 166s 285ms/step - loss: 1242.5977 - mae: 29.3460 - val_loss: 1298.4619 - val_mae: 30.2363
# Epoch 9/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 209s 298ms/step - loss: 1220.3928 - mae: 29.1409 - val_loss: 1287.1354 - val_mae: 30.0736
# Epoch 10/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 203s 299ms/step - loss: 1193.2698 - mae: 28.6665 - val_loss: 1247.6124 - val_mae: 29.6994
# Epoch 11/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 174s 299ms/step - loss: 1138.6532 - mae: 27.8014 - val_loss: 1219.8973 - val_mae: 28.9297
# Epoch 12/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 192s 282ms/step - loss: 1126.3624 - mae: 27.5047 - val_loss: 1203.3362 - val_mae: 29.5853
# Epoch 13/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 213s 300ms/step - loss: 1103.9465 - mae: 27.3035 - val_loss: 1258.1135 - val_mae: 28.3256
# Epoch 14/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 300ms/step - loss: 1069.2463 - mae: 26.6459 - val_loss: 1353.5392 - val_mae: 31.2639
# Epoch 15/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 203s 302ms/step - loss: 1036.5228 - mae: 26.0274 - val_loss: 1183.5891 - val_mae: 29.1623
# Epoch 16/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 192s 285ms/step - loss: 1011.4892 - mae: 25.6854 - val_loss: 1146.4377 - val_mae: 28.3288
# Epoch 17/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 211s 301ms/step - loss: 987.0827 - mae: 25.2524 - val_loss: 1168.0662 - val_mae: 26.4717
# Epoch 18/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 300ms/step - loss: 982.2736 - mae: 25.0574 - val_loss: 1067.4293 - val_mae: 25.5950
# Epoch 19/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━
100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 174s 299ms/step - loss: 537.8178 - mae: 17.3976 - val_loss: 617.6577 - val_mae: 18.9004
# Epoch 71/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 175s 301ms/step - loss: 536.3829 - mae: 17.3686 - val_loss: 833.5785 - val_mae: 20.0869
# Epoch 72/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 201s 300ms/step - loss: 538.4625 - mae: 17.4399 - val_loss: 738.5337 - val_mae: 19.0196
# Epoch 73/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 194s 286ms/step - loss: 539.9382 - mae: 17.4247 - val_loss: 636.2123 - val_mae: 18.4480
# Epoch 74/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 212s 303ms/step - loss: 522.1578 - mae: 17.0779 - val_loss: 642.9325 - val_mae: 18.4781
# Epoch 75/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 201s 302ms/step - loss: 522.5591 - mae: 17.1683 - val_loss: 570.6070 - val_mae: 17.5953
# Epoch 76/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 302ms/step - loss: 514.8246 - mae: 17.0496 - val_loss: 1078.7151 - val_mae: 22.4331
# Epoch 77/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 192s 286ms/step - loss: 551.2728 - mae: 17.6449 - val_loss: 593.1397 - val_mae: 17.6959
# Epoch 78/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 175s 301ms/step - loss: 537.5479 - mae: 17.3159 - val_loss: 793.8488 - val_mae: 20.4060
# Epoch 79/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 175s 301ms/step - loss: 532.5236 - mae: 17.2659 - val_loss: 1065.0579 - val_mae: 22.2448
# Epoch 80/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 301ms/step - loss: 526.0134 - mae: 17.2074 - val_loss: 713.9681 - val_mae: 19.2694
# Epoch 81/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 301ms/step - loss: 506.0978 - mae: 16.8893 - val_loss: 662.3649 - val_mae: 18.4076
# Epoch 82/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 193s 286ms/step - loss: 514.4756 - mae: 16.9600 - val_loss: 1068.7633 - val_mae: 22.5871
# Epoch 83/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 286ms/step - loss: 544.2869 - mae: 17.5291 - val_loss: 676.2587 - val_mae: 19.7209
# Epoch 84/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 211s 302ms/step - loss: 532.6102 - mae: 17.2809 - val_loss: 617.4211 - val_mae: 18.4584
# Epoch 85/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 202s 301ms/step - loss: 503.9640 - mae: 16.7997 - val_loss: 660.0323 - val_mae: 18.3879
# 849/849 ━━━━━━━━━━━━━━━━━━━━ 39s 45ms/step
# Test RMSE: 22.17
# Test MAE: 15.41
#
# --- Experiment 1 Report ---
# RMSE: 22.17
# MAE: 15.41
# Settings: {'dataset_name': 'FD004', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 2/2 with config: FD004, Scaler: minmax, Seq Length: 60, Piecewise RUL: False, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 175s 283ms/step - loss: 15476.9941 - mae: 97.0598 - val_loss: 7604.4941 - val_mae: 65.2549
# Epoch 2/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 210s 296ms/step - loss: 7764.5845 - mae: 65.4919 - val_loss: 5160.0923 - val_mae: 58.1539
# Epoch 3/100
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 203s