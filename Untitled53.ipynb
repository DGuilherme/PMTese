# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/PMTese/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install python-docx

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.14.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Configs

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs_all = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
]

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 100,
        "lstm_units": [128],
        "dropout_rate": 0.1,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 1e-4,
        "head_size": 64,
        "num_heads": 4,
        "ff_dim": 128,
        "num_transformer_blocks": 2
    }
]

# %%
def run_transformer_experiment(config):

    dataset_name = config["dataset_name"]
    scaler_type = config["scaler_type"]
    seq_length = config["seq_length"]
    use_piecewise_rul = config["use_piecewise_rul"]
    max_rul_cap = config["max_rul_cap"]
    useful_sensor_cols = config["feature_set"]
    batch_size = config["batch_size"]
    epochs = config["epochs"]
    lstm_units = config["lstm_units"]
    dropout_rate = config["dropout_rate"]
    loss_function = config["loss_function"]
    head_size= config["head_size"]
    num_heads=4
    ff_dim=128
    num_transformer_blocks=2
    mlp_units=[128]
    dropout=0.1
    mlp_dropout=0.1
    embedding_dim=64

    column_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor{i}' for i in range(1, 22)]
    train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
    test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
    rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)

    train_data.columns = column_names
    test_data.columns = column_names
    rul_data.columns = ['RUL']
    rul_data['id'] = range(1, len(rul_data) + 1)

    max_cycle = train_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'cycle_max'})
    train_data = train_data.merge(max_cycle, on='id')
    train_data['RUL'] = train_data['cycle_max'] - train_data['cycle']
    train_data.drop(columns=['cycle_max'], inplace=True)

    max_cycle_test = test_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
    test_data = test_data.merge(max_cycle_test, on='id')
    test_data = test_data.merge(rul_data, on='id')
    test_data['RUL'] = test_data['RUL'] + test_data['max_cycle'] - test_data['cycle']
    test_data.drop(columns=['max_cycle'], inplace=True)

    if use_piecewise_rul:
        train_data['RUL'] = train_data['RUL'].clip(upper=max_rul_cap)
        test_data['RUL'] = test_data['RUL'].clip(upper=max_rul_cap)

    train_data = train_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]
    test_data = test_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]

    scaler = MinMaxScaler() if scaler_type == 'minmax' else StandardScaler()
    train_data[useful_sensor_cols] = scaler.fit_transform(train_data[useful_sensor_cols])
    test_data[useful_sensor_cols] = scaler.transform(test_data[useful_sensor_cols])

    def create_sequences(data, sequence_length):
        sequences, labels = [], []
        for engine_id in data['id'].unique():
            engine_data = data[data['id'] == engine_id]
            X = engine_data[useful_sensor_cols].values
            y = engine_data['RUL'].values
            for i in range(len(X) - sequence_length + 1):
                sequences.append(X[i:i+sequence_length])
                labels.append(y[i+sequence_length-1])
        return np.array(sequences), np.array(labels)

    X_train, y_train = create_sequences(train_data, seq_length)
    X_test, y_test = create_sequences(test_data, seq_length)

    def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
        # Attention block
        attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
        attn_output = layers.Dropout(dropout)(attn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)  # Add & Norm

        # Feed Forward block
        ff_output = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        ff_output = layers.Dropout(dropout)(ff_output)
        ff_output = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(ff_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + ff_output)  # Add & Norm

        return x


    def build_model(input_shape):
        inputs = keras.Input(shape=input_shape)
        x = inputs

        # https://www.tensorflow.org/tutorials/structured_data/time_series
        x = layers.Dense(embedding_dim)(inputs)

        for _ in range(num_transformer_blocks):
            x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D()(x)
        for units in mlp_units:
            x = layers.Dense(units, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(1)(x)  # Predict RUL
        return keras.Model(inputs, outputs)

    model = build_model(X_train.shape[1:])
    model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["mae"])

    early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=64,
        callbacks=[early_stopping]
    )

    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Test RMSE: {rmse:.2f}")
    print(f"Test MAE: {mae:.2f}")

    return model, y_pred, rmse, mae

# %%
def compare_datasets(test_configs):
    results = []
    num_configs = len(test_configs)
    for i, config in enumerate(test_configs):
        print(f"Running experiment {i + 1}/{num_configs} with config: {config['dataset_name']}, Scaler: {config['scaler_type']}, Seq Length: {config['seq_length']}, Piecewise RUL: {config['use_piecewise_rul']}, Features: {', '.join(config['feature_set'])}")
        model, y_pred, rmse, mae = run_transformer_experiment(config)
        result = {
            'dataset': config['dataset_name'],
            'rmse': rmse,
            'mae': mae,
            'config': config
        }
        results.append(result)
        print(f"\n--- Experiment {i + 1} Report ---")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")
        print(f"Settings: {config}")
    return results

# %%
from docx import Document

def save_experiment_to_docx(results_list, output_path="/content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_transformer.docx"):
    doc = Document()
    doc.add_heading("Transformer RUL Prediction Experiment Results", level=1)

    for i, res in enumerate(results_list):
        doc.add_heading(f"Experiment {i + 1} – Dataset: {res['dataset']}", level=2)
        doc.add_paragraph(f"RMSE: {res['rmse']:.2f}")
        doc.add_paragraph(f"MAE: {res['mae']:.2f}")
        doc.add_paragraph("Settings Used:")
        for key, value in res['config'].items():
            doc.add_paragraph(f"- {key}: {value}", style='List Bullet')

        doc.add_paragraph("")  # Blank line between experiments

    doc.save(output_path)
    print(f"✅ Document saved to {output_path}")

# %%
results = compare_datasets(test_configs)
save_experiment_to_docx(results)

# Create summary table
summary_df = pd.DataFrame([
    {
        'Dataset': r['dataset'],
        'RMSE': r['rmse'],
        'MAE': r['mae'],
        'Scaler': r['config']['scaler_type'],
        'Seq Length': r['config']['seq_length'],
        'Piecewise RUL': r['config']['use_piecewise_rul'],
        'Features': ', '.join(r['config']['feature_set'])
    }
    for r in results
])

display(summary_df)
# Out:
# Running experiment 1/16 with config: FD001, Scaler: minmax, Seq Length: 50, Piecewise RUL: True, Features: sensor2, sensor3, sensor4, sensor7, sensor8, sensor9, sensor11, sensor12, sensor13, sensor15, sensor17, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 59s 252ms/step - loss: 6436.2510 - mae: 69.0467 - val_loss: 6130.8662 - val_mae: 67.3016
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 242ms/step - loss: 4851.9346 - mae: 58.3742 - val_loss: 4353.8374 - val_mae: 56.0007
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 253ms/step - loss: 3281.9553 - mae: 47.6183 - val_loss: 2794.8147 - val_mae: 45.6293
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 237ms/step - loss: 1974.5555 - mae: 36.3640 - val_loss: 1373.2324 - val_mae: 30.5163
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 233ms/step - loss: 955.0823 - mae: 24.2497 - val_loss: 709.0646 - val_mae: 21.9549
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 234ms/step - loss: 491.1914 - mae: 17.2310 - val_loss: 372.8021 - val_mae: 15.9328
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 245ms/step - loss: 303.4979 - mae: 13.6727 - val_loss: 251.7527 - val_mae: 12.9938
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 247ms/step - loss: 236.8154 - mae: 11.9982 - val_loss: 199.5944 - val_mae: 11.3123
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 247ms/step - loss: 202.9847 - mae: 10.8999 - val_loss: 196.4740 - val_mae: 10.8551
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - loss: 208.3865 - mae: 10.8347 - val_loss: 181.4174 - val_mae: 10.3122
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 248ms/step - loss: 182.0220 - mae: 9.9281 - val_loss: 173.1099 - val_mae: 9.9637
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 244ms/step - loss: 185.6692 - mae: 10.0076 - val_loss: 185.4488 - val_mae: 10.3251
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 247ms/step - loss: 171.3931 - mae: 9.6795 - val_loss: 169.0645 - val_mae: 9.6411
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 250ms/step - loss: 174.1500 - mae: 9.6994 - val_loss: 164.1472 - val_mae: 9.3632
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 236ms/step - loss: 169.8525 - mae: 9.4950 - val_loss: 203.2682 - val_mae: 10.6774
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 242ms/step - loss: 165.7978 - mae: 9.3773 - val_loss: 162.4102 - val_mae: 9.4122
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 245ms/step - loss: 168.7828 - mae: 9.4881 - val_loss: 215.9518 - val_mae: 11.0345
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 249ms/step - loss: 166.1208 - mae: 9.4173 - val_loss: 161.5587 - val_mae: 9.5021
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 246ms/step - loss: 163.4838 - mae: 9.3550 - val_loss: 161.3941 - val_mae: 9.4188
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - loss: 166.7035 - mae: 9.4273 - val_loss: 156.4204 - val_mae: 9.0966
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 236ms/step - loss: 165.0319 - mae: 9.3593 - val_loss: 191.4454 - val_mae: 10.5045
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 234ms/step - loss: 164.0000 - mae: 9.3983 - val_loss: 155.3659 - val_mae: 8.8038
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 235ms/step - loss: 165.8634 - mae: 9.3954 - val_loss: 176.6032 - val_mae: 10.1693
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 249ms/step - loss: 152.5759 - mae: 9.0042 - val_loss: 169.8283 - val_mae: 9.7073
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - loss: 157.7608 - mae: 9.1457 - val_loss: 162.0560 - val_mae: 9.5875
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 235ms/step - loss: 144.4540 - mae: 8.7706 - val_loss: 171.3881 - val_mae: 9.7373
# Epoch 27/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - loss: 149.2778 - mae: 8.8501 - val_loss: 186.6118 - val_mae: 10.3724
# Epoch 28/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 244ms/step - loss: 147.3991 - mae: 8.8661 - val_loss: 169.1980 - val_mae: 9.8884
# Epoch 29/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 240ms/step - loss: 150.7479 - mae: 8.9361 - val_loss: 184.9436 - val_mae: 10.1945
# Epoch 30/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 247ms/step - loss: 150.8151 - mae: 8.9427 - val_loss: 162.2104 - val_mae: 9.5798
# Epoch 31/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 246ms/step - loss: 141.9253 - mae: 8.6900 - val_loss: 162.0016 - val_mae: 9.5330
# Epoch 32/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 248ms/step - loss: 140.6623 - mae: 8.6801 - val_loss: 164.8477 - val_mae: 9.5250
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step
# Test RMSE: 14.25
# Test MAE: 9.94
#
# --- Experiment 1 Report ---
# RMSE: 14.25
# MAE: 9.94
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 50, 'lstm_units': [100, 50], 'dropout_rate': 0.2, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 2/16 with config: FD001, Scaler: minmax, Seq Length: 50, Piecewise RUL: False, Features: sensor2, sensor3, sensor4, sensor7, sensor8, sensor9, sensor11, sensor12, sensor13, sensor15, sensor17, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 59s 250ms/step - loss: 8581.6533 - mae: 75.3708 - val_loss: 10668.1855 - val_mae: 80.7415
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 244ms/step - loss: 6247.8428 - mae: 61.7167 - val_loss: 8085.2520 - val_mae: 68.2567
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - loss: 4458.6597 - mae: 51.1403 - val_loss: 6038.2129 - val_mae: 59.0760
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - loss: 3203.9888 - mae: 43.5434 - val_loss: 4091.4993 - val_mae: 44.3595
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 246ms/step - loss: 1879.3168 - mae: 29.2958 - val_loss: 2837.2673 - val_mae: 35.5161
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 241ms/step - loss: 1263.2135 - mae: 23.1573 - val_loss: 2154.1042 - val_mae: 29.8384
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - loss: 918.8877 - mae: 19.6154 - val_loss: 1756.1417 - val_mae: 26.6956
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 245ms/step - loss: 840.9581 - mae: 18.6330 - val_loss: 1776.3320 - val_mae: 27.2602
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 238ms/step - loss: 792.9559 - mae: 18.1106 - val_loss: 1529.9684 - val_mae: 25.3046
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - loss: 761.7446 - mae: 17.7345 - val_loss: 1552.4551 - val_mae: 25.7451
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 230ms/step - loss: 691.1901 - mae: 17.0412 - val_loss: 1360.2968 - val_mae: 23.9283
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 235ms/step - loss: 655.1951 - mae: 16.6189 - val_loss: 1828.0605 - val_mae: 27.3695
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 244ms/step - loss: 685.6826 - mae: 16.8995 - val_loss: 1273.9598 - val_mae: 23.1615
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - loss: 626.2621 - mae: 16.0975 - val_loss: 1562.0747 - val_mae: 25.2479
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 230ms/step - loss: 617.0907 - mae: 16.0442 - val_loss: 1269.7468 - val_mae: 22.9277
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 242ms/step - loss: 565.4720 - mae: 15.3821 - val_loss: 1487.4119 - val_mae: 24.7675
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - loss: 587.8474 - mae: 15.5272 - val_loss: 1392.6036 - val_mae: 23.8542
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 240ms/step - loss: 519.8887 - mae: 14.8355 - val_loss: 1379.9744 - val_mae: 23.8771
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 243ms/step - loss: 521.6870 - mae: 14.8599 - val_loss: 1586.3254 - val_mae: 25.2085
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 236ms/step - loss: 518.3630 - mae: 14.9823 - val_loss: 1256.6858 - val_mae: 22.9321
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 244ms/step - loss: 459.7990 - mae: 14.2001 - val_loss: 1409.7185 - val_mae: 23.9658
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 231ms/step - loss: 448.5818 - mae: 14.0272 - val_loss: 1394.9996 - val_mae: 23.7396
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 236ms/step - loss: 428.1374 - mae: 13.9115 - val_loss: 1252.9719 - val_mae: 23.0861
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 45s 229ms/step - loss: 417.5978 - mae: 13.6081 - val_loss: 1791.5472 - val_mae: 26.1132
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 227ms/step - loss: 423.8886 - mae: 13.6634 - val_loss: 1444.6951 - val_mae: 24.1703
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 240ms/step - loss: 408.2458 - mae: 13.6912 - val_loss: 1836.3446 - val_mae: 26.6409
# Epoch 27/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 241ms/step - loss: 382.2716 - mae: 13.3344 - val_loss: 1576.2014 - val_mae: 24.9474
# Epoch 28/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 45s 230ms/step - loss: 350.2998 - mae: 12.7907 - val_loss: 1751.7319 - val_mae: 25.9523
# Epoch 29/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 243ms/step - loss: 347.3444 - mae: 12.8414 - val_loss: 1618.3845 - val_mae: 24.7418
# Epoch 30/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 229ms/step - loss: 354.1036 - mae: 12.8943 - val_loss: 1451.0702 - val_mae: 24.1170
# Epoch 31/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 242ms/step - loss: 321.2739 - mae: 12.5648 - val_loss: 1586.6689 - val_mae: 24.4105
# Epoch 32/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 45s 229ms/step - loss: 323.9047 - mae: 12.4421 - val_loss: 1728.3114 - val_mae: 25.4935
# Epoch 33/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 234ms/step - loss: 294.8638 - mae: 11.9677 - val_loss: 1673.7665 - val_mae: 25.2216
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step
# Test RMSE: 39.20
# Test MAE: 27.94
#
# --- Experiment 2 Report ---
# RMSE: 39.20
# MAE: 27.94
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': False, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 3/16 with config: FD001, Scaler: minmax, Seq Length: 60, Piecewise RUL: True, Features: sensor2, sensor3, sensor4, sensor7, sensor8, sensor9, sensor11, sensor12, sensor13, sensor15, sensor17, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 62s 283ms/step - loss: 6026.3945 - mae: 66.3990 - val_loss: 5821.6343 - val_mae: 64.9503
# Epoch 2/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - loss: 4561.2334 - mae: 56.2927 - val_loss: 4315.6543 - val_mae: 55.1717
# Epoch 3/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 288ms/step - loss: 3202.3511 - mae: 46.4233 - val_loss: 2939.2661 - val_mae: 46.0370
# Epoch 4/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 291ms/step - loss: 2173.0867 - mae: 38.5156 - val_loss: 1639.2058 - val_mae: 31.9538
# Epoch 5/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 79s 277ms/step - loss: 1094.1591 - mae: 24.7657 - val_loss: 847.3530 - val_mae: 23.0459
# Epoch 6/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 286ms/step - loss: 566.2451 - mae: 17.8193 - val_loss: 442.1628 - val_mae: 16.9154
# Epoch 7/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 285ms/step - loss: 341.7791 - mae: 14.1677 - val_loss: 300.2119 - val_mae: 14.0319
# Epoch 8/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 286ms/step - loss: 239.2491 - mae: 11.9077 - val_loss: 221.9195 - val_mae: 12.0953
# Epoch 9/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 287ms/step - loss: 213.1048 - mae: 11.1917 - val_loss: 215.7491 - val_mae: 11.7094
# Epoch 10/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 284ms/step - loss: 190.3943 - mae: 10.4471 - val_loss: 316.7293 - val_mae: 13.2287
# Epoch 11/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 297ms/step - loss: 187.2211 - mae: 10.2324 - val_loss: 222.3404 - val_mae: 11.2535
# Epoch 12/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - loss: 170.6379 - mae: 9.6645 - val_loss: 242.2534 - val_mae: 11.6148
# Epoch 13/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 293ms/step - loss: 179.7280 - mae: 9.8790 - val_loss: 180.0855 - val_mae: 10.1443
# Epoch 14/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 283ms/step - loss: 169.0509 - mae: 9.5233 - val_loss: 323.2504 - val_mae: 13.0388
# Epoch 15/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 293ms/step - loss: 193.5054 - mae: 10.2618 - val_loss: 219.7182 - val_mae: 11.0119
# Epoch 16/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 283ms/step - loss: 158.7959 - mae: 9.2885 - val_loss: 225.7277 - val_mae: 11.1558
# Epoch 17/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 295ms/step - loss: 162.4604 - mae: 9.3066 - val_loss: 181.3474 - val_mae: 10.1469
# Epoch 18/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 286ms/step - loss: 148.6337 - mae: 8.9483 - val_loss: 238.5059 - val_mae: 11.3754
# Epoch 19/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - loss: 155.7042 - mae: 9.2425 - val_loss: 202.2616 - val_mae: 10.4944
# Epoch 20/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 288ms/step - loss: 143.4224 - mae: 8.7244 - val_loss: 190.6228 - val_mae: 10.1076
# Epoch 21/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 285ms/step - loss: 152.4509 - mae: 9.0906 - val_loss: 176.3908 - val_mae: 9.6967
# Epoch 22/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - loss: 143.9054 - mae: 8.7392 - val_loss: 175.3103 - val_mae: 9.8461
# Epoch 23/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - loss: 144.2955 - mae: 8.7748 - val_loss: 218.5329 - val_mae: 11.0236
# Epoch 24/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 281ms/step - loss: 139.4240 - mae: 8.6021 - val_loss: 187.3939 - val_mae: 10.0616
# Epoch 25/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 289ms/step - loss: 138.5768 - mae: 8.5703 - val_loss: 191.8716 - val_mae: 10.1639
# Epoch 26/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 280ms/step - loss: 136.9556 - mae: 8.5446 - val_loss: 219.6144 - val_mae: 10.6961
# Epoch 27/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 51s 279ms/step - loss: 145.9924 - mae: 8.7762 - val_loss: 216.4940 - val_mae: 11.0831
# Epoch 28/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 285ms/step - loss: 134.5857 - mae: 8.4734 - val_loss: 194.8938 - val_mae: 10.0565
# Epoch 29/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - loss: 124.3292 - mae: 8.1201 - val_loss: 203.6615 - val_mae: 10.2510
# Epoch 30/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 282ms/step - loss: 124.3295 - mae: 8.1514 - val_loss: 191.8838 - val_mae: 9.7608
# Epoch 31/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 285ms/step - loss: 119.5908 - mae: 7.9939 - val_loss: 211.1505 - val_mae: 10.4997
# Epoch 32/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 51s 275ms/step - loss: 125.8444 - mae: 8.1557 - val_loss: 239.9120 - val_mae: 11.0720
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step
# Test RMSE: 14.19
# Test MAE: 10.54
#
# --- Experiment 3 Report ---
# RMSE: 14.19
# MAE: 10.54
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 4/16 with config: FD001, Scaler: minmax, Seq Length: 60, Piecewise RUL: False, Features: sensor2, sensor3, sensor4, sensor7, sensor8, sensor9, sensor11, sensor12, sensor13, sensor15, sensor17, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 66s 298ms/step - loss: 8008.9458 - mae: 72.8555 - val_loss: 9963.0635 - val_mae: 77.9938
# Epoch 2/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 295ms/step - loss: 6144.4258 - mae: 61.1345 - val_loss: 7901.5283 - val_mae: 67.4332
# Epoch 3/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 295ms/step - loss: 4550.0762 - mae: 51.5418 - val_loss: 6022.4385 - val_mae: 58.3196
# Epoch 4/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 283ms/step - loss: 3263.1809 - mae: 41.9434 - val_loss: 4096.2515 - val_mae: 43.4783
# Epoch 5/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 289ms/step - loss: 1878.8135 - mae: 28.1204 - val_loss: 2794.5906 - val_mae: 33.2657
# Epoch 6/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 283ms/step - loss: 1190.2134 - mae: 20.8469 - val_loss: 2055.1304 - val_mae: 27.7336
# Epoch 7/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 290ms/step - loss: 909.8419 - mae: 18.4192 - val_loss: 1650.1541 - val_mae: 25.0536
# Epoch 8/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 282ms/step - loss: 751.8616 - mae: 16.7606 - val_loss: 1562.6954 - val_mae: 25.2137
# Epoch 9/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - loss: 663.6177 - mae: 16.0807 - val_loss: 1642.8336 - val_mae: 25.8420
# Epoch 10/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - loss: 683.4091 - mae: 16.7499 - val_loss: 1211.0715 - val_mae: 22.3009
# Epoch 11/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - loss: 598.9608 - mae: 15.3803 - val_loss: 1489.5378 - val_mae: 24.6528
# Epoch 12/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 277ms/step - loss: 583.9922 - mae: 14.9608 - val_loss: 1248.5591 - val_mae: 23.0379
# Epoch 13/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 271ms/step - loss: 538.0640 - mae: 14.6312 - val_loss: 1054.3400 - val_mae: 21.2192
# Epoch 14/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 281ms/step - loss: 537.3392 - mae: 14.6466 - val_loss: 1040.1478 - val_mae: 21.5020
# Epoch 15/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 50s 271ms/step - loss: 533.0262 - mae: 14.6714 - val_loss: 964.0721 - val_mae: 20.6705
# Epoch 16/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 283ms/step - loss: 529.0558 - mae: 14.7432 - val_loss: 1101.1979 - val_mae: 21.3877
# Epoch 17/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 290ms/step - loss: 501.4641 - mae: 14.4023 - val_loss: 1007.2468 - val_mae: 20.6160
# Epoch 18/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 54s 291ms/step - loss: 434.6120 - mae: 13.4361 - val_loss: 1266.7515 - val_mae: 22.4551
# Epoch 19/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 54s 290ms/step - loss: 477.3769 - mae: 14.0105 - val_loss: 1344.0630 - val_mae: 23.0968
# Epoch 20/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 293ms/step - loss: 446.5593 - mae: 13.7332 - val_loss: 1154.7109 - val_mae: 21.4996
# Epoch 21/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 285ms/step - loss: 413.9672 - mae: 13.2139 - val_loss: 965.0280 - val_mae: 20.4000
# Epoch 22/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 282ms/step - loss: 410.5768 - mae: 13.4532 - val_loss: 1452.4204 - val_mae: 24.0720
# Epoch 23/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 288ms/step - loss: 404.0985 - mae: 13.1773 - val_loss: 1524.4034 - val_mae: 24.2499
# Epoch 24/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 294ms/step - loss: 380.4256 - mae: 12.9015 - val_loss: 1141.4330 - val_mae: 21.6719
# Epoch 25/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 283ms/step - loss: 355.8684 - mae: 12.6652 - val_loss: 1451.6863 - val_mae: 23.7341
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step
# Test RMSE: 32.54
# Test MAE: 23.14
#
# --- Experiment 4 Report ---
# RMSE: 32.54
# MAE: 23.14
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': False, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 5/16 with config: FD001, Scaler: minmax, Seq Length: 50, Piecewise RUL: True, Features: sensor2, sensor3, sensor4, sensor7, sensor9, sensor11, sensor12, sensor14, sensor15, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 57s 243ms/step - loss: 6335.5259 - mae: 68.4694 - val_loss: 6051.7002 - val_mae: 66.8028
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 234ms/step - loss: 4924.5278 - mae: 58.9657 - val_loss: 4386.4956 - val_mae: 56.2112
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 241ms/step - loss: 3305.8364 - mae: 47.7696 - val_loss: 2889.2983 - val_mae: 46.3185
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 244ms/step - loss: 2215.9207 - mae: 39.6086 - val_loss: 1568.1671 - val_mae: 32.6606
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 242ms/step - loss: 1079.9315 - mae: 25.8003 - val_loss: 835.4958 - val_mae: 24.2569
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 241ms/step - loss: 616.4847 - mae: 19.6460 - val_loss: 449.7909 - val_mae: 17.3083
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 240ms/step - loss: 333.4187 - mae: 14.2598 - val_loss: 287.0518 - val_mae: 13.9324
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - loss: 248.4357 - mae: 12.2010 - val_loss: 240.4030 - val_mae: 12.2276
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 233ms/step - loss: 218.7717 - mae: 11.3041 - val_loss: 237.0192 - val_mae: 11.9198
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 241ms/step - loss: 206.6863 - mae: 10.8123 - val_loss: 276.8956 - val_mae: 12.4820
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 241ms/step - loss: 195.4676 - mae: 10.4005 - val_loss: 234.3641 - val_mae: 11.3196
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 230ms/step - loss: 188.1043 - mae: 10.0995 - val_loss: 190.0737 - val_mae: 10.5484
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 239ms/step - loss: 189.9739 - mae: 10.1626 - val_loss: 193.2773 - val_mae: 10.4393
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 235ms/step - loss: 180.1585 - mae: 9.8503 - val_loss: 193.5263 - val_mae: 10.4792
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 241ms/step - loss: 180.2779 - mae: 9.7798 - val_loss: 213.1793 - val_mae: 10.8789
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 241ms/step - loss: 176.9686 - mae: 9.7627 - val_loss: 195.7300 - val_mae: 10.2947
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - loss: 172.7428 - mae: 9.6090 - val_loss: 203.9668 - val_mae: 10.7692
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - loss: 175.4851 - mae: 9.6797 - val_loss: 207.8841 - val_mae: 10.4472
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 231ms/step - loss: 174.7939 - mae: 9.6100 - val_loss: 241.3469 - val_mae: 11.2558
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 231ms/step - loss: 167.6470 - mae: 9.4095 - val_loss: 187.2542 - val_mae: 10.1152
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 45s 231ms/step - loss: 173.7448 - mae: 9.5678 - val_loss: 242.8847 - val_mae: 11.5205
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 240ms/step - loss: 171.6225 - mae: 9.5182 - val_loss: 203.9381 - val_mae: 10.5370
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 235ms/step - loss: 162.0179 - mae: 9.2274 - val_loss: 207.4718 - val_mae: 10.5876
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 240ms/step - loss: 165.8319 - mae: 9.3005 - val_loss: 196.3742 - val_mae: 10.2410
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - loss: 159.4273 - mae: 9.1577 - val_loss: 229.4209 - val_mae: 11.4189
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 85s 241ms/step - loss: 158.4863 - mae: 9.1864 - val_loss: 242.2022 - val_mae: 11.2162
# Epoch 27/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - loss: 157.5752 - mae: 9.0683 - val_loss: 263.8255 - val_mae: 11.7651
# Epoch 28/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 235ms/step - loss: 150.8997 - mae: 8.8453 - val_loss: 221.3104 - val_mae: 11.1703
# Epoch 29/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 243ms/step - loss: 145.7168 - mae: 8.7939 - val_loss: 218.5030 - val_mae: 10.7148
# Epoch 30/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 230ms/step - loss: 145.9287 - mae: 8.7866 - val_loss: 271.3088 - val_mae: 12.1056
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step
# Test RMSE: 14.92
# Test MAE: 11.14
#
# --- Experiment 5 Report ---
# RMSE: 14.92
# MAE: 11.14
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 6/16 with config: FD001, Scaler: minmax, Seq Length: 50, Piecewise RUL: False, Features: sensor2, sensor3, sensor4, sensor7, sensor9, sensor11, sensor12, sensor14, sensor15, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 59s 255ms/step - loss: 8763.6943 - mae: 76.7379 - val_loss: 11303.0225 - val_mae: 83.8906
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 245ms/step - loss: 6952.1128 - mae: 65.4591 - val_loss: 9081.6445 - val_mae: 72.9953
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - loss: 5180.1338 - mae: 55.4650 - val_loss: 6895.3755 - val_mae: 62.6985
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 243ms/step - loss: 3569.6167 - mae: 43.5415 - val_loss: 4690.5107 - val_mae: 47.2366
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - loss: 2241.4985 - mae: 31.7719 - val_loss: 3330.9165 - val_mae: 38.4446
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 249ms/step - loss: 1489.5492 - mae: 24.8827 - val_loss: 2511.4453 - val_mae: 31.8085
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 250ms/step - loss: 1052.7849 - mae: 20.6126 - val_loss: 2032.9243 - val_mae: 28.5049
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 247ms/step - loss: 914.2682 - mae: 19.1492 - val_loss: 1786.4347 - val_mae: 28.1256
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 233ms/step - loss: 847.0141 - mae: 18.7456 - val_loss: 1845.2046 - val_mae: 27.4172
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - loss: 774.1257 - mae: 17.6919 - val_loss: 1625.5669 - val_mae: 25.6139
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 235ms/step - loss: 747.7582 - mae: 17.3117 - val_loss: 1564.4216 - val_mae: 25.1514
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 85s 249ms/step - loss: 757.4615 - mae: 17.4990 - val_loss: 1452.1689 - val_mae: 24.7358
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 241ms/step - loss: 679.8288 - mae: 16.8174 - val_loss: 1545.3230 - val_mae: 24.8654
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 244ms/step - loss: 666.8633 - mae: 16.4571 - val_loss: 1547.4178 - val_mae: 24.5968
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 246ms/step - loss: 654.6834 - mae: 16.2961 - val_loss: 1328.2496 - val_mae: 24.7460
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 234ms/step - loss: 664.7338 - mae: 16.5737 - val_loss: 1311.4551 - val_mae: 24.0807
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 245ms/step - loss: 631.4642 - mae: 16.0775 - val_loss: 1919.4921 - val_mae: 26.8193
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - loss: 615.3324 - mae: 15.7600 - val_loss: 1644.2080 - val_mae: 25.1517
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - loss: 548.7906 - mae: 15.1162 - val_loss: 1626.3948 - val_mae: 25.1514
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 248ms/step - loss: 602.5074 - mae: 15.9535 - val_loss: 1689.7039 - val_mae: 25.4481
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 48s 246ms/step - loss: 569.5533 - mae: 15.3470 - val_loss: 1453.8751 - val_mae: 24.1721
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 249ms/step - loss: 545.0713 - mae: 15.1796 - val_loss: 1699.5192 - val_mae: 25.7501
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 240ms/step - loss: 473.1790 - mae: 14.3433 - val_loss: 1863.5970 - val_mae: 26.8988
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - loss: 495.0242 - mae: 14.7554 - val_loss: 1883.3102 - val_mae: 27.0063
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 46s 233ms/step - loss: 433.2550 - mae: 13.8970 - val_loss: 2174.8091 - val_mae: 28.9484
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 241ms/step - loss: 435.1843 - mae: 13.9915 - val_loss: 1741.1635 - val_mae: 26.2498
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step
# Test RMSE: 35.27
# Test MAE: 25.99
#
# --- Experiment 6 Report ---
# RMSE: 35.27
# MAE: 25.99
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 50, 'use_piecewise_rul': False, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 7/16 with config: FD001, Scaler: minmax, Seq Length: 60, Piecewise RUL: True, Features: sensor2, sensor3, sensor4, sensor7, sensor9, sensor11, sensor12, sensor14, sensor15, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 61s 281ms/step - loss: 6087.6621 - mae: 66.8934 - val_loss: 5968.0571 - val_mae: 65.8944
# Epoch 2/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 49s 266ms/step - loss: 4696.8843 - mae: 56.9477 - val_loss: 4577.4150 - val_mae: 56.8814
# Epoch 3/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 54s 291ms/step - loss: 3467.1421 - mae: 48.3524 - val_loss: 3212.6641 - val_mae: 47.8844
# Epoch 4/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 289ms/step - loss: 2417.1052 - mae: 41.0646 - val_loss: 2045.3036 - val_mae: 36.9468
# Epoch 5/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 290ms/step - loss: 1378.3560 - mae: 28.6662 - val_loss: 1052.7073 - val_mae: 25.8806
# Epoch 6/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 79s 273ms/step - loss: 699.4323 - mae: 20.0808 - val_loss: 562.7870 - val_mae: 18.8251
# Epoch 7/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 283ms/step - loss: 391.4346 - mae: 15.1235 - val_loss: 326.1473 - val_mae: 14.4780
# Epoch 8/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 280ms/step - loss: 269.0446 - mae: 12.6499 - val_loss: 241.2959 - val_mae: 12.5498
# Epoch 9/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 51s 275ms/step - loss: 218.3511 - mae: 11.2340 - val_loss: 215.8544 - val_mae: 11.4403
# Epoch 10/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 282ms/step - loss: 188.0413 - mae: 10.3101 - val_loss: 230.7854 - val_mae: 11.7729
# Epoch 11/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 50s 270ms/step - loss: 187.0999 - mae: 10.1772 - val_loss: 186.4628 - val_mae: 10.2119
# Epoch 12/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 284ms/step - loss: 192.6917 - mae: 10.2059 - val_loss: 181.4411 - val_mae: 10.3118
# Epoch 13/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 293ms/step - loss: 172.2003 - mae: 9.6731 - val_loss: 175.9722 - val_mae: 9.8696
# Epoch 14/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 280ms/step - loss: 172.3929 - mae: 9.6367 - val_loss: 233.0336 - val_mae: 11.4794
# Epoch 15/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 275ms/step - loss: 166.9327 - mae: 9.5074 - val_loss: 212.4289 - val_mae: 11.0158
# Epoch 16/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 281ms/step - loss: 159.6561 - mae: 9.2589 - val_loss: 200.8521 - val_mae: 10.5105
# Epoch 17/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 271ms/step - loss: 166.5274 - mae: 9.4418 - val_loss: 218.8646 - val_mae: 10.8893
# Epoch 18/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 280ms/step - loss: 164.5236 - mae: 9.3668 - val_loss: 207.2349 - val_mae: 10.8646
# Epoch 19/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 85s 295ms/step - loss: 153.4737 - mae: 9.0276 - val_loss: 173.0701 - val_mae: 9.8437
# Epoch 20/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 79s 282ms/step - loss: 159.1198 - mae: 9.2172 - val_loss: 214.8698 - val_mae: 10.8127
# Epoch 21/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 283ms/step - loss: 157.4882 - mae: 9.1608 - val_loss: 209.4656 - val_mae: 10.4126
# Epoch 22/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 280ms/step - loss: 151.1453 - mae: 8.9163 - val_loss: 281.8556 - val_mae: 12.1888
# Epoch 23/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 289ms/step - loss: 150.4962 - mae: 8.7679 - val_loss: 190.6080 - val_mae: 10.2323
# Epoch 24/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 281ms/step - loss: 151.4712 - mae: 8.8957 - val_loss: 175.2403 - val_mae: 9.8156
# Epoch 25/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 281ms/step - loss: 150.4851 - mae: 8.8265 - val_loss: 189.9595 - val_mae: 10.3137
# Epoch 26/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 287ms/step - loss: 144.1730 - mae: 8.6369 - val_loss: 214.9129 - val_mae: 10.8304
# Epoch 27/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 281ms/step - loss: 137.8405 - mae: 8.5651 - val_loss: 196.7024 - val_mae: 10.2463
# Epoch 28/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 282ms/step - loss: 137.8329 - mae: 8.4560 - val_loss: 313.3482 - val_mae: 13.2104
# Epoch 29/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - loss: 144.8217 - mae: 8.7190 - val_loss: 257.3344 - val_mae: 11.6622
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step
# Test RMSE: 14.45
# Test MAE: 10.96
#
# --- Experiment 7 Report ---
# RMSE: 14.45
# MAE: 10.96
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': True, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 8/16 with config: FD001, Scaler: minmax, Seq Length: 60, Piecewise RUL: False, Features: sensor2, sensor3, sensor4, sensor7, sensor9, sensor11, sensor12, sensor14, sensor15, sensor20, sensor21
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 62s 287ms/step - loss: 8083.7764 - mae: 73.3955 - val_loss: 10411.1338 - val_mae: 80.3394
# Epoch 2/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 54s 290ms/step - loss: 6470.6182 - mae: 63.4555 - val_loss: 8556.9092 - val_mae: 70.7404
# Epoch 3/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 51s 275ms/step - loss: 5049.7046 - mae: 54.1663 - val_loss: 6651.2876 - val_mae: 61.3158
# Epoch 4/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 285ms/step - loss: 3695.6191 - mae: 46.1416 - val_loss: 4783.9819 - val_mae: 47.9813
# Epoch 5/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 296ms/step - loss: 2257.2803 - mae: 31.8996 - val_loss: 3340.2708 - val_mae: 38.0685
# Epoch 6/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 281ms/step - loss: 1538.5620 - mae: 24.3877 - val_loss: 2383.9028 - val_mae: 30.3185
# Epoch 7/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 290ms/step - loss: 1086.2040 - mae: 20.2859 - val_loss: 1888.7303 - val_mae: 27.1589
# Epoch 8/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 290ms/step - loss: 885.0892 - mae: 18.3179 - val_loss: 1594.4414 - val_mae: 24.5742
# Epoch 9/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 299ms/step - loss: 711.2704 - mae: 16.5568 - val_loss: 1482.6215 - val_mae: 24.2515
# Epoch 10/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 286ms/step - loss: 695.7349 - mae: 16.3537 - val_loss: 1411.5535 - val_mae: 23.5665
# Epoch 11/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 83s 291ms/step - loss: 596.4878 - mae: 15.2046 - val_loss: 1228.9679 - val_mae: 22.6692
# Epoch 12/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 52s 284ms/step - loss: 623.3543 - mae: 15.6819 - val_loss: 1224.0239 - val_mae: 22.0365
# Epoch 13/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 284ms/step - loss: 578.7739 - mae: 15.0494 - val_loss: 1104.4269 - val_mae: 21.3895
# Epoch 14/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 281ms/step - loss: 589.0357 - mae: 15.3801 - val_loss: 1299.4990 - val_mae: 22.6214
# Epoch 15/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 280ms/step - loss: 545.5079 - mae: 14.5858 - val_loss: 1290.1237 - val_mae: 22.8702
# Epoch 16/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 84s 290ms/step - loss: 534.3052 - mae: 14.5674 - val_loss: 1127.9053 - val_mae: 21.6370
# Epoch 17/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 80s 280ms/step - loss: 541.0861 - mae: 15.0097 - val_loss: 1110.1243 - val_mae: 21.3523
# Epoch 18/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 277ms/step - loss: 533.2615 - mae: 14.5669 - val_loss: 1349.9642 - val_mae: 23.3368
# Epoch 19/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 271ms/step - loss: 481.2071 - mae: 13.7923 - val_loss: 1305.4500 - val_mae: 22.7374
# Epoch 20/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 81s 268ms/step - loss: 449.5812 - mae: 13.7234 - val_loss: 1417.6981 - val_mae: 23.4655
# Epoch 21/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 289ms/step - loss: 448.3913 - mae: 13.4577 - val_loss: 1122.2916 - val_mae: 21.5422
# Epoch 22/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 82s 290ms/step - loss: 411.9832 - mae: 13.1898 - val_loss: 1727.0353 - val_mae: 26.0382
# Epoch 23/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 79s 276ms/step - loss: 373.6129 - mae: 12.6823 - val_loss: 1385.1943 - val_mae: 23.4621
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step
# Test RMSE: 33.12
# Test MAE: 23.93
#
# --- Experiment 8 Report ---
# RMSE: 33.12
# MAE: 23.93
# Settings: {'dataset_name': 'FD001', 'scaler_type': 'minmax', 'seq_length': 60, 'use_piecewise_rul': False, 'max_rul_cap': 125, 'feature_set': ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21'], 'batch_size': 64, 'epochs': 100, 'lstm_units': [128], 'dropout_rate': 0.1, 'loss_function': 'mse', 'optimizer': 'adam', 'learning_rate': 0.0001, 'head_size': 64, 'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2}
# Running experiment 9/16 with config: FD002, Scaler: minmax, Seq Length: 50, Piecewise RUL: True, Features: setting1, setting2, setting3, sensor2, sensor8, sensor14
# /tmp/ipython-input-4-3801735877.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-4-3801735877.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# Epoch 1/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 134s 239ms/step - loss: 6122.3325 - mae: 67.0052 - val_loss: 3010.4092 - val_mae: 45.9278
# Epoch 2/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 118s 230ms/step - loss: 2466.3342 - mae: 42.4133 - val_loss: 1720.5725 - val_mae: 36.6430
# Epoch 3/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 233ms/step - loss: 1727.8234 - mae: 36.6985 - val_loss: 1718.3618 - val_mae: 36.5574
# Epoch 4/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 231ms/step - loss: 1724.7692 - mae: 36.6011 - val_loss: 1718.8203 - val_mae: 36.5530
# Epoch 5/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 229ms/step - loss: 1717.3149 - mae: 36.5153 - val_loss: 1718.4985 - val_mae: 36.5544
# Epoch 6/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 230ms/step - loss: 1737.5087 - mae: 36.7885 - val_loss: 1720.2604 - val_mae: 36.5462
# Epoch 7/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 118s 229ms/step - loss: 1729.4363 - mae: 36.7114 - val_loss: 1530.5400 - val_mae: 33.9803
# Epoch 8/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 145s 235ms/step - loss: 1523.0588 - mae: 33.7022 - val_loss: 1472.9352 - val_mae: 33.0695
# Epoch 9/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 234ms/step - loss: 1479.2859 - mae: 32.9990 - val_loss: 1439.1958 - val_mae: 32.5571
# Epoch 10/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 121s 236ms/step - loss: 1470.0649 - mae: 32.8509 - val_loss: 1464.8264 - val_mae: 32.9536
# Epoch 11/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 234ms/step - loss: 1457.8055 - mae: 32.7159 - val_loss: 1455.0227 - val_mae: 32.4689
# Epoch 12/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 233ms/step - loss: 1456.5104 - mae: 32.6840 - val_loss: 1447.2227 - val_mae: 32.6125
# Epoch 13/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 233ms/step - loss: 1446.1233 - mae: 32.5127 - val_loss: 1376.1604 - val_mae: 31.7335
# Epoch 14/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 235ms/step - loss: 1413.5962 - mae: 32.1533 - val_loss: 1453.1945 - val_mae: 32.8658
# Epoch 15/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 123s 240ms/step - loss: 1404.2131 - mae: 32.0407 - val_loss: 1448.0813 - val_mae: 31.9928
# Epoch 16/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 239ms/step - loss: 1401.6556 - mae: 31.9278 - val_loss: 1403.4045 - val_mae: 32.0724
# Epoch 17/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 241ms/step - loss: 1398.7493 - mae: 31.8857 - val_loss: 1472.1155 - val_mae: 31.6633
# Epoch 18/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 236ms/step - loss: 1379.8207 - mae: 31.5766 - val_loss: 1324.8746 - val_mae: 31.1463
# Epoch 19/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 146s 244ms/step - loss: 1333.1790 - mae: 31.0911 - val_loss: 1269.1847 - val_mae: 30.4830
# Epoch 20/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 139s 239ms/step - loss: 1326.8622 - mae: 30.9335 - val_loss: 1254.8174 - val_mae: 30.1761
# Epoch 21/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 119s 232ms/step - loss: 1283.9825 - mae: 30.2998 - val_loss: 1230.9934 - val_mae: 29.8743
# Epoch 22/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 120s 233ms/step - loss: 1281.4674 - mae: 30.2633 - val_loss: 1442.6611 - val_mae: 31.4772
# Epoch 23/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 235ms/step - loss: 1234.5321 - mae: 29.5473 - val_loss: 1283.8861 - val_mae: 30.0417
# Epoch 24/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 237ms/step - loss: 1221.8467 - mae: 29.3956 - val_loss: 1229.1129 - val_mae: 29.5185
# Epoch 25/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 120s 235ms/step - loss: 1194.0981 - mae: 29.0238 - val_loss: 1355.7030 - val_mae: 30.3680
# Epoch 26/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 118s 229ms/step - loss: 1156.7928 - mae: 28.5038 - val_loss: 1254.1324 - val_mae: 29.2235
# Epoch 27/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 118s 230ms/step - loss: 1143.4850 - mae: 28.2097 - val_loss: 1190.1438 - val_mae: 28.8108
# Epoch 28/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 230ms/step - loss: 1138.3876 - mae: 28.0774 - val_loss: 1469.4268 - val_mae: 30.5784
# Epoch 29/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 230ms/step - loss: 1112.0824 - mae: 27.8025 - val_loss: 1147.8162 - val_mae: 28.1970
# Epoch 30/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 232ms/step - loss: 1115.0247 - mae: 27.7902 - val_loss: 1124.0298 - val_mae: 27.7137
# Epoch 31/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 232ms/step - loss: 1084.1703 - mae: 27.2811 - val_loss: 1244.1025 - val_mae: 28.3401
# Epoch 32/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 229ms/step - loss: 1062.1016 - mae: 26.9272 - val_loss: 1508.6941 - val_mae: 31.4902
# Epoch 33/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 120s 233ms/step - loss: 1013.9114 - mae: 26.2902 - val_loss: 1135.9686 - val_mae: 27.7705
# Epoch 34/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 140s 229ms/step - loss: 1036.3550 - mae: 26.5175 - val_loss: 1025.9974 - val_mae: 26.6472
# Epoch 35/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 234ms/step - loss: 974.5914 - mae: 25.7165 - val_loss: 1021.3911 - val_mae: 26.0981
# Epoch 36/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 142s 235ms/step - loss: 1009.3668 - mae: 25.9928 - val_loss: 1087.0613 - val_mae: 26.6557
# Epoch 37/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 137s 226ms/step - loss: 980.7834 - mae: 25.7305 - val_loss: 1115.0588 - val_mae: 27.2570
# Epoch 38/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 119s 232ms/step - loss: 919.9731 - mae: 24.7769 - val_loss: 1001.3374 - val_mae: 26.0556
# Epoch 39/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 116s 226ms/step - loss: 952.2250 - mae: 25.2599 - val_loss: 1100.3875 - val_mae: 26.0257
# Epoch 40/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 119s 233ms/step - loss: 881.8909 - mae: 24.0976 - val_loss: 1250.1929 - val_mae: 28.5095
# Epoch 41/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 231ms/step - loss: 912.9583 - mae: 24.5303 - val_loss: 1253.9285 - val_mae: 27.1101
# Epoch 42/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 229ms/step - loss: 966.7778 - mae: 25.2903 - val_loss: 883.2947 - val_mae: 24.0957
# Epoch 43/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 144s 233ms/step - loss: 855.1157 - mae: 23.7535 - val_loss: 1373.7922 - val_mae: 27.7151
# Epoch 44/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 236ms/step - loss: 861.7160 - mae: 23.7239 - val_loss: 944.4106 - val_mae: 24.9621
# Epoch 45/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 120s 235ms/step - loss: 872.8680 - mae: 23.8885 - val_loss: 1564.5140 - val_mae: 31.6509
# Epoch 46/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 233ms/step - loss: 851.5747 - mae: 23.5160 - val_loss: 840.1327 - val_mae: 23.2988
# Epoch 47/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 236ms/step - loss: 817.6188 - mae: 23.0610 - val_loss: 839.1022 - val_mae: 23.2676
# Epoch 48/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 143s 238ms/step - loss: 799.2906 - mae: 22.7572 - val_loss: 886.8293 - val_mae: 23.7931
# Epoch 49/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 141s 235ms/step - loss: 802.2772 - mae: 22.8517 - val_loss: 929.7587 - val_mae: 24.0951
# Epoch 50/100
# 513/513 ━━━━━━━━━━━━━━━━━━━━ 121s 236ms/step - loss: 784.6319 - mae: 22.6228 - val_loss: 862.6434 - val_mae: 23.4482
# Epoch 51/100
# 236/513 ━━━━━━━━━━━━━━━━━━━━ 1:00 220ms/step - loss: 803.6899 - mae: 22.8237
