# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/PMTese/blob/main/Untitled52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install python-docx

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Congifs

# %%
# mais curto
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']


test_configs = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    }
]

# %%
FD001_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD002_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD001_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor9', 'sensor11', 'sensor12', 'sensor14', 'sensor15', 'sensor20', 'sensor21']
FD002_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs = [
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD001",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD001_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 30,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD002",
        "scaler_type": "standard",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD002_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
]

# %%
# mais curto 3 e 4
FD003_usefulfeatures_correlation = ['sensor2', 'sensor3', 'sensor4', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor15', 'sensor17', 'sensor20', 'sensor21']
FD004_usefulfeatures_correlation = ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
FD003_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']
FD004_usefulfeatures_boruta = ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']

test_configs = [
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    }
,
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    }
]

# %%
test_configs_FD003 = [
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD003",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD003_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    }
]

test_configs_FD004 = [{
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_correlation,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 50,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": True,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    },
    {
        "dataset_name": "FD004",
        "scaler_type": "minmax",
        "seq_length": 60,
        "use_piecewise_rul": False,
        "max_rul_cap": 125,
        "feature_set": FD004_usefulfeatures_boruta,
        "batch_size": 64,
        "epochs": 50,
        "lstm_units": [100, 50],
        "dropout_rate": 0.2,
        "loss_function": "mse",
        "optimizer": "adam",
        "learning_rate": 0.001
    }
]

# %% [markdown]
# # Main Function with config parameters

# %%
def run_lstm_experiment(config):
    # Extract settings from config
    dataset_name = config['dataset_name']
    scaler_type = config['scaler_type']
    seq_length = config['seq_length']
    use_piecewise_rul = config['use_piecewise_rul']
    max_rul_cap = config['max_rul_cap']
    useful_sensor_cols = config['feature_set']
    batch_size = config['batch_size']
    epochs = config['epochs']
    lstm_units = config['lstm_units']
    dropout_rate = config['dropout_rate']
    loss_function = config['loss_function']
    optimizer_name = config['optimizer']
    learning_rate = config['learning_rate']

    # Load data
    column_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor{i}' for i in range(1, 22)]
    train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
    test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
    rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)

    train_data.columns = column_names
    test_data.columns = column_names
    rul_data.columns = ['RUL']
    rul_data['id'] = range(1, len(rul_data) + 1)

    # Compute RUL for training
    max_cycle = train_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'cycle_max'})
    train_data = train_data.merge(max_cycle, on='id')
    train_data['RUL'] = train_data['cycle_max'] - train_data['cycle']
    if use_piecewise_rul:
        train_data['RUL'] = train_data['RUL'].clip(upper=max_rul_cap)
    train_data.drop(columns=['cycle_max'], inplace=True)

    # Compute RUL for testing
    max_cycle_test = test_data.groupby('id')['cycle'].max().reset_index().rename(columns={'cycle': 'max_cycle'})
    test_data = test_data.merge(max_cycle_test, on='id')
    test_data = test_data.merge(rul_data, on='id')
    test_data['RUL'] = test_data['RUL'] + test_data['max_cycle'] - test_data['cycle']
    if use_piecewise_rul:
        test_data['RUL'] = test_data['RUL'].clip(upper=max_rul_cap)
    test_data.drop(columns=['max_cycle'], inplace=True)

    # Select useful features
    train_data = train_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]
    test_data = test_data[['id', 'cycle'] + useful_sensor_cols + ['RUL']]

    # Normalize
    if scaler_type == 'minmax':
        scaler = MinMaxScaler()
    elif scaler_type == 'standard':
        scaler = StandardScaler()
    else:
        raise ValueError("Unsupported scaler type.")
    train_data[useful_sensor_cols] = scaler.fit_transform(train_data[useful_sensor_cols])
    test_data[useful_sensor_cols] = scaler.transform(test_data[useful_sensor_cols])

    # Sequence creation function
    def create_sequences(data, seq_length, features):
        sequences, labels = [], []
        for engine_id in data['id'].unique():
            engine_data = data[data['id'] == engine_id].reset_index(drop=True)
            if len(engine_data) < seq_length:
                continue
            for i in range(len(engine_data) - seq_length):
                seq = engine_data.iloc[i:i + seq_length][features].values
                label = engine_data.iloc[i + seq_length - 1]['RUL']
                sequences.append(seq)
                labels.append(label)
        return np.array(sequences), np.array(labels)

    # Prepare data
    X_train, y_train = create_sequences(train_data, seq_length, useful_sensor_cols)
    X_test, y_test = create_sequences(test_data, seq_length, useful_sensor_cols)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(lstm_units[0], return_sequences=True, input_shape=(seq_length, len(useful_sensor_cols))))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(lstm_units[1]))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))

    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer.")

    model.compile(optimizer=optimizer, loss=loss_function)

    # Train model
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=batch_size, epochs=epochs, verbose=0)

    # Evaluate
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    # Return detailed result
    return {
        "dataset": dataset_name,
        "rmse": rmse,
        "mae": mae,
        "model": model,
        "config": config,
        "history": history
    }

# %% [markdown]
# # Execution and Results

# %%
from docx import Document

def save_experiment_to_docx(results_list, output_path="/content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_20250905_FD004.docx"):
    doc = Document()
    doc.add_heading("LSTM Experiment Results for RUL Prediction", level=1)

    for i, res in enumerate(results_list):
        doc.add_heading(f"Experiment {i + 1} – Dataset: {res['dataset']}", level=2)
        doc.add_paragraph(f"RMSE: {res['rmse']:.2f}")
        doc.add_paragraph(f"MAE: {res['mae']:.2f}")
        doc.add_paragraph("Settings Used:")
        for key, value in res['config'].items():
            doc.add_paragraph(f"- {key}: {value}", style='List Bullet')

        doc.add_paragraph("")  # Blank line between experiments

    doc.save(output_path)
    print(f"✅ Document saved to {output_path}")

# %%
results = []

for config in test_configs_FD004:
    result = run_lstm_experiment(config)
    results.append(result)

    print(f"\n--- {result['dataset']} Run Report ---")
    print(f"RMSE: {result['rmse']:.2f}")
    print(f"MAE: {result['mae']:.2f}")
    print("Settings:")
    for key, value in result['config'].items():
        print(f"  - {key}: {value}")

# Save to Word document
save_experiment_to_docx(results)

# Create summary table
summary_df = pd.DataFrame([
    {
        'Dataset': r['dataset'],
        'RMSE': r['rmse'],
        'MAE': r['mae'],
        'Scaler': r['config']['scaler_type'],
        'Seq Length': r['config']['seq_length'],
        'Piecewise RUL': r['config']['use_piecewise_rul'],
        'Features': ', '.join(r['config']['feature_set'])
    }
    for r in results
])

display(summary_df)
# Out:
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 913/913 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
#
# --- FD004 Run Report ---
# RMSE: 36.21
# MAE: 34.00
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 50
#   - use_piecewise_rul: True
#   - max_rul_cap: 125
#   - feature_set: ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 913/913 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
#
# --- FD004 Run Report ---
# RMSE: 101.31
# MAE: 75.94
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 50
#   - use_piecewise_rul: False
#   - max_rul_cap: 125
#   - feature_set: ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step
#
# --- FD004 Run Report ---
# RMSE: 29.48
# MAE: 26.69
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 60
#   - use_piecewise_rul: True
#   - max_rul_cap: 125
#   - feature_set: ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step
#
# --- FD004 Run Report ---
# RMSE: 101.03
# MAE: 75.79
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 60
#   - use_piecewise_rul: False
#   - max_rul_cap: 125
#   - feature_set: ['setting1', 'setting2', 'setting3', 'sensor2', 'sensor8', 'sensor14']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 913/913 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
#
# --- FD004 Run Report ---
# RMSE: 17.19
# MAE: 12.03
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 50
#   - use_piecewise_rul: True
#   - max_rul_cap: 125
#   - feature_set: ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 913/913 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step
#
# --- FD004 Run Report ---
# RMSE: 68.41
# MAE: 49.12
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 50
#   - use_piecewise_rul: False
#   - max_rul_cap: 125
#   - feature_set: ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step
#
# --- FD004 Run Report ---
# RMSE: 15.83
# MAE: 11.40
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 60
#   - use_piecewise_rul: True
#   - max_rul_cap: 125
#   - feature_set: ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# /tmp/ipython-input-2864085135.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/train_{dataset_name}.txt/train_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/test_{dataset_name}.txt/test_{dataset_name}.txt', delim_whitespace=True, header=None)
# /tmp/ipython-input-2864085135.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_data = pd.read_csv(f'/content/drive/MyDrive/Python/predictive-maintenance-main/datasets/cmapss/RUL_{dataset_name}.txt/RUL_{dataset_name}.txt', delim_whitespace=True, header=None)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step
#
# --- FD004 Run Report ---
# RMSE: 79.26
# MAE: 57.55
# Settings:
#   - dataset_name: FD004
#   - scaler_type: minmax
#   - seq_length: 60
#   - use_piecewise_rul: False
#   - max_rul_cap: 125
#   - feature_set: ['sensor2', 'sensor3', 'sensor4', 'sensor6', 'sensor7', 'sensor8', 'sensor9', 'sensor11', 'sensor12', 'sensor13', 'sensor14', 'sensor15', 'sensor21']
#   - batch_size: 64
#   - epochs: 50
#   - lstm_units: [100, 50]
#   - dropout_rate: 0.2
#   - loss_function: mse
#   - optimizer: adam
#   - learning_rate: 0.001
# ✅ Document saved to /content/drive/MyDrive/Python/predictive-maintenance-main/experiment_report_20250905_FD004.docx
#   Dataset        RMSE        MAE  Scaler  Seq Length  Piecewise RUL  \
# 0   FD004   36.213452  33.999421  minmax          50           True
# 1   FD004  101.306693  75.943339  minmax          50          False
# 2   FD004   29.479318  26.691173  minmax          60           True
# 3   FD004  101.034274  75.788247  minmax          60          False
# 4   FD004   17.188626  12.026082  minmax          50           True
# 5   FD004   68.410738  49.116709  minmax          50          False
# 6   FD004   15.830125  11.396660  minmax          60           True
# 7   FD004   79.255619  57.545673  minmax          60          False
#
#                                             Features
# 0  setting1, setting2, setting3, sensor2, sensor8...
# 1  setting1, setting2, setting3, sensor2, sensor8...
# 2  setting1, setting2, setting3, sensor2, sensor8...
# 3  setting1, setting2, setting3, sensor2, sensor8...
# 4  sensor2, sensor3, sensor4, sensor6, sensor7, s...
# 5  sensor2, sensor3, sensor4, sensor6, sensor7, s...
# 6  sensor2, sensor3, sensor4, sensor6, sensor7, s...
# 7  sensor2, sensor3, sensor4, sensor6, sensor7, s...
